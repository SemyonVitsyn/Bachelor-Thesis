# %%
import pandas as pd

# Загрузка файлов
df1 = pd.read_csv('csv/Статьи_Регламенты-Медицина.csv')
df2 = pd.read_csv('csv/Статьи_Регламенты-Металлургия.csv')
df3 = pd.read_csv('csv/Статьи_Регламенты-Нефтегаз.csv')

# df4 = pd.read_csv('csv/Техническая_документация-Инструкции_по_эксплуатации_техники.csv')
# df5 = pd.read_csv('csv/Техническая_документация-Руководства_к_РФ_ПО.csv')
# df6 = pd.read_csv('csv/Техническая_документация-Linux.csv')

# df7 = pd.read_csv('csv/Финансовые_документы-Аналитические_отчеты.csv')
# df8 = pd.read_csv('csv/Финансовые_документы-Отчеты_об_AI_отрасли.csv')
# df9 = pd.read_csv('csv/Финансовые_документы-Финансовые_отчеты_компаний.csv')

# Объединение
combined_df = pd.concat([df1, df2, df3], ignore_index=True)

# Сохранение
combined_df.to_csv('benchmark_short.csv', index=False)

# %%
df = pd.read_csv('benchmark_short.csv')

# %%
print(df)
# Out:
#         Домен документов Сет документов  \
# 0    Статьи и регламенты       Медицина
# 1    Статьи и регламенты       Медицина
# 2    Статьи и регламенты       Медицина
# 3    Статьи и регламенты       Медицина
# 4    Статьи и регламенты       Медицина
# ..                   ...            ...
# 226  Статьи и регламенты       Нефтегаз
# 227  Статьи и регламенты       Нефтегаз
# 228  Статьи и регламенты       Нефтегаз
# 229  Статьи и регламенты       Нефтегаз
# 230  Статьи и регламенты       Нефтегаз
#
#                                     Название документа  \
# 0    Эпидемиология_диагностика_клиническая_симптома...
# 1    Эпидемиология_диагностика_клиническая_симптома...
# 2    Эпидемиология_диагностика_клиническая_симптома...
# 3    Эпидемиология_диагностика_клиническая_симптома...
# 4    Эпидемиология_диагностика_клиническая_симптома...
# ..                                                 ...
# 226              Нефтяная_и_газовая_промышленность.pdf
# ...

# %%
df = pd.read_csv('benchmark.csv')

# %%
print(df)
# Out:
#          Домен документов              Сет документов  \
# 0     Статьи и регламенты                    Медицина
# 1     Статьи и регламенты                    Медицина
# 2     Статьи и регламенты                    Медицина
# 3     Статьи и регламенты                    Медицина
# 4     Статьи и регламенты                    Медицина
# ..                    ...                         ...
# 669  Финансовые документы  Финансовые отчеты компаний
# 670  Финансовые документы  Финансовые отчеты компаний
# 671  Финансовые документы  Финансовые отчеты компаний
# 672  Финансовые документы  Финансовые отчеты компаний
# 673  Финансовые документы  Финансовые отчеты компаний
#
#                                     Название документа  \
# 0    Эпидемиология_диагностика_клиническая_симптома...
# 1    Эпидемиология_диагностика_клиническая_симптома...
# 2    Эпидемиология_диагностика_клиническая_симптома...
# 3    Эпидемиология_диагностика_клиническая_симптома...
# ...

# %%
print(df.iloc[1]['Ответ'])
# Out:
# Формальдегид повышает риск развития плоскоклеточного рака и аденокарциномы. Иприт, асбест, никель и радий вызывают развитие плоскоклеточного рака, а древесная пыль и работы с кожей предрасполагают к развитию аденокарциномы. Вирус папилломы человека также влияет на малигнизацию при инвертированной папилломе и плоскоклеточном раке.
