# %%
import pandas as pd
import ast
import asyncio
import os
from typing import List, Dict
from tqdm.asyncio import tqdm_asyncio
import json
import random
from queue import deque

# %% [markdown]
# # WEBGLM

# %%
with open('webglm.jsonl', 'r') as f:
    data = [json.loads(line) for line in f]

# %%
with open('test/webglm_test.jsonl', 'w') as f:
    for item in data[:1000]:
        json.dump(item, f)
        f.write('\n')

# %%
with open('val/webglm_val.jsonl', 'w') as f:
    for item in data[1000:4100]:
        json.dump(item, f)
        f.write('\n')

# %%
with open('train/webglm_train.jsonl', 'w') as f:
    for item in data[4100:]:
        json.dump(item, f)
        f.write('\n')

# %% [markdown]
# # RAFT

# %%
data = []

with open('webglm_raft.jsonl', 'r') as f:
    data = [json.loads(line) for line in f]

# %%
print(len(data))
# Out:
# 48468

# %%
with open('val/webglm_raft_val.jsonl', 'w') as f:
    for item in data[:1000]:
        json.dump(item, f)
        f.write('\n')
    for item in data[-100:]:
        json.dump(item, f)
        f.write('\n')

# %%
# with open('val/webglm_raft_val.jsonl', 'w') as f:
#     for item in data[1000:4000]:
#         json.dump(item, f)
#         f.write('\n')
#     for item in data[-400:-100]:
#         json.dump(item, f)
#         f.write('\n')

# %%
with open('train/webglm_raft_train.jsonl', 'w') as f:
    for item in data[1000:-100]:
        json.dump(item, f)
        f.write('\n')

# %% [markdown]
# # Lost In The Middle

# %%
df = pd.read_excel('webglm_full.xlsx')

def create_llama_dataset(df: pd.DataFrame) -> List[Dict]:
    dataset = []
    for _, row in df.iterrows():
        question = row['question']
        answer = str(row['answer'])
        examples = ast.literal_eval(row["references"]) if isinstance(row['references'], str) else []
        
        dataset_item = {
            "question": question,
            "answer": answer,
            "references": examples
        }
        dataset.append(dataset_item)
    return dataset


dataset = create_llama_dataset(df)[:100]

max_refs = 9
storage = deque(maxlen=max_refs)

for item in dataset:
    storage.append(item)

# %%
SYSTEM_PROMPT = (
    "Ты — экспертная система Compressa RAG, "
    "предоставляющая точные и релевантные ответы на вопросы, "
    "используя только предоставленную контекстную информацию. "
    "Отвечай на русском языке."
)
REJECT_ANSW = "К сожалению, ответа на вопрос нет в упомянутых источниках"

def get_summary_prompt(context_list, question):
    context = ''
    for i, c in enumerate(context_list):
        context += f'Источник [{i+1}]:'+"\n"+c+"\n\n"

    prompt = (
        f"# Контекстная информация:\n\n{context}\n\n"
        "---\n"
        "# Инструкции:\n\n"
        "1. Дай полный и краткий ответ на вопрос, используя только информацию из контекста.\n"
        "2. Указывай источники, с которыми работаешь, например: [1].\n"
        "3. Ответ должен содержать хотя бы одну ссылку на источник.\n"
        f"4. Ответ гарантированно содержится в указанных источниках.\n"
        "5. Не используй знания вне предоставленного контекста.\n\n"
        f"# Вопрос:\n\n{question}\n\n"
    )
    return prompt

def update_refs_number(answer, old_numbers, new_numbers):
    for old, new in zip(old_numbers, new_numbers):
        answer = answer.replace(f"[{old}]", f"[{new}]")
    return answer

# %%
with open("test/lost_in_the_middle.jsonl", "w") as output:
    for idx, item in enumerate(dataset[:10]):
        
        true_refs = item["references"]

        for golden_position in range(0, 10, 1):
            all_refs = []
            shift = 0
            for j in range(10):
                if golden_position == j:
                    all_refs += true_refs
                    shift = 1
                else:
                    all_refs += storage[j-shift]["references"]

            new_numbers = [all_refs.index(ref) + 1 for ref in true_refs]
            answer = update_refs_number(item["answer"], list(range(1, len(new_numbers)+1)), new_numbers)
        
            data = ({
                "messages": [
                    {"content": SYSTEM_PROMPT, "role": "system"},
                    {"content": get_summary_prompt(all_refs, item["question"]), "role": "user"},
                ],
                "golden_answer": answer,
                "question_idx": idx,
                "golden_position": golden_position,
            })

            json.dump(data, output)
            output.write('\n')

        storage.append(item)

# %%
with open('test/lost_in_the_middle.jsonl', 'r') as f:
    print(len(f.readlines()))
# Out:
# 100

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
from tqdm import tqdm
from transformers import AutoModelForCausalLM
import json
import torch

tokens_count = 0
arr = []

with open('test/lost_in_the_middle.jsonl', 'r') as f:
    dataset = f.readlines()

tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen2.5-3B")

for row in dataset:
    item = json.loads(row)
    # print(item['messages'][1])
    # break
    l = len(tokenizer.encode(item['messages'][1]['content'], add_special_tokens=False))
    tokens_count += l
    arr.append(l)

# %%
import numpy as np

arr = np.sort(np.array(arr))

print(f"question_avg {tokens_count / len(dataset)}")
print(f"question_max {arr[-1]}")
print(f"question_80 {arr[int(len(dataset)*0.8)]}")
print(f"question_95 {arr[int(len(dataset)*0.95)]}")
print(f"question_99 {arr[int(len(dataset)*0.99)]}")
# Out:
# question_avg 7005.0
# question_max 7803
# question_80 7541
# question_95 7803
# question_99 7803

# %%
import json

with open('test/lost_in_the_middle.jsonl', 'r') as f:
    item = json.loads(f.readlines()[1])
    print(item['messages'][1]['content'])

    print(item['golden_answer'])
# Out:
# # Контекстная информация:
#
# Источник [1]:
# Eli5
#
# Источник [2]:
# Мы не "теряем" пресную воду в прямом смысле. Мы просто используем ограниченный запас, который у нас есть, с большей скоростью, чем природа его пополняет.
#
# Источник [3]:
# Ответ заключается в том, что людям для выживания необходим доступ к пресной жидкой воде, которая является лишь небольшой частью общего водного цикла. Когда городские чиновники говорят вам не тратить воду напрасно, они имеют в виду, что вы не должны бездумно перенаправлять воду из части водного цикла, доступной для использования человеком, в часть, не доступную для использования человеком. Согласно книге "Вода в кризисе", под редакцией Питера Г. Глейка, только 0,77% воды на Земле находится в виде пресной, жидкой воды на поверхности земли и в земле. Остальная вода находится в соленых океанах и озерах, заключена в льду или в атмосфере. Позволять воде стекать в раковину, пока вы берете перекус, обычно означает, что эта вода выходит из части водного цикла, доступной и используемой человеком. Имея это в виду, тратить воду напрасно не наносит прямого ущерба глобальной среде, поскольку вода не уничтожается. Скорее, такая траты воды вредит людям, так как оставляет их с меньшим доступом к используемой воде. Кроме того, чрезмерное расходование воды может навредить местной среде, так как изымает слишком много используемой воды из натуральной экосистемы.
#
# Источник [4]:
# Что такое часть водного цикла, доступная для использования человеком? Ответ
#
# Источник [5]:
# Родители, городские чиновники и экологи часто говорят нам
#
# Источник [6]:
# Как видно из этих моментов, большинство этих игр задуманы для прорыва прямо через центр. Тренер надеется, что все защитники будут заблокированы; бегущий нападающий сможет обойти одного из игроков и в итоге оказаться в зоне вбивания мяча.
#
# Источник [7]:
# В профессиональном и студенческом футболе атакующая сторона имеет 40 секунд с момента окончания предыдущего хода для выполнения следующего хода. Команда, стремящаяся убить время, будет допускать, чтобы игровой таймер (который фиксирует время, оставшееся до необходимости выполнения хода) истекал насколько это возможно, прежде чем выполнить свой следующий ход. В НФЛ это особенно заметно из-за существования двухминутного предупреждения. Если отстающая команда не имеет тайм-аутов, а ведущая команда владеет мячом с первой попыткой на двухминутном предупреждении, она может эффективно убить время и выиграть игру, не выполняя больше ни одного успешного хода. За две минуты до конца (120 секунд) атакующая сторона может принять три "колена", по одному на каждой из попыток (используя все 40 секунд игрового таймера на каждой), и позволить игровому таймеру истечь, прежде чем нужно будет выполнить ход на четвертой попытке. Подобная ситуация может сложиться и в случае достижения первой попытки внутри двухминутного предупреждения. Эта практика обычно называется "Формация Победы", когда атакующая сторона выстраивается в плотную защитную "V" формацию, чтобы минимизировать шансы на потерю мяча или другую передачу.
#
# Источник [8]:
# Бегущие нападающие прорываются через центр, потому что это самый короткий путь к зоне вбивания мяча. Игры часто задумываются для того, чтобы убрать защитников с пути, чтобы бегущий нападающий мог бежать прямо как можно быстрее. Защита часто отлично справляется с задачей сбивать блоки или мешать пути бегущего нападающего, создавая кучу чаще всего.
#
# Источник [9]:
# Если вы достаточно часто будете прорываться через центр, лайнбекеры и защитники начнут бежать к линии скриммиджа. Это идеальная возможность бросить мяч над их головами или в освободившиеся зоны.
#
# Источник [10]:
# Задержка времени в ассоциативном футболе состоит из двух форм
#
# Источник [11]:
# Insane Clown Posse - это американская группа в стиле хорроркор-хип-хоп, состоящая из Джозефа Брюса (Violent J) и Джозефа Утслера (Shaggy 2 Dope). Они привлекли к себе некое подобие культа преданных фанатов, называемых Juggalos. Juggalos узнаваемы по их лицевой росписи и часто видны с продукцией, одобренной ICP, такой как Faygo. Теперь их считают "нетрадиционной бандой" Федеральным бюро расследований.
#
# Источник [12]:
# Insane Clown Posse - это американская хип-хоп группа из Детройта, Мичиган, в составе Violent J и Shaggy 2 Dope. Эта группа является центром субкультуры juggalo, которая лежит в основе культовых убеждений Гамзи Макара.
#
# Источник [13]:
# В 2011 году ФБР классифицировало группу фанатов Insane Clown Posse, Juggalos, как "слабо организованную гибридную банду"
#
# Источник [14]:
# На прошлых выходных в Вашингтоне, округ Колумбия, клоуноликие последователи хорроркор-рэп группы Insane Clown Posse, известные как Juggalos, собрались на своеобразное семейное собрание, чтобы протестовать против ФБР, которое отказалось отменить классификацию "банды", наложенную на них правительством в 2011 году. Согласно недопонятым участникам, приехавшим со всей страны, чтобы объединиться — семья это то, что на самом деле значит быть Juggalo, и они никогда не хотели бы причинить кому-либо вред.
#
# Источник [15]:
# Insane Clown Posse - это хип-хоп группа, которая фокусируется на текстах песен о социальных проблемах, таких как насилие и бедность (Neely 2014). По мере распространения имени фаната Juggalo, их музыка начала достигать людей, страдающих от этих и других трудностей. Большинство Juggalos живут в бедности по всей США, и многим не хватает денег на основные продукты питания или одежду (Echlin 2003). Вместо того, чтобы позволить своей бедности обескуражить их, Juggalos выбирают принять её. Подобно другим субкультурам, таким как скинхеды, Juggalos принимают в свою семью любого и празднуют разнообразие социально-экономического статуса друг друга. Даже женщины-Juggalos имеют свое собственное название, Juggalettes, доказывая тот факт, что Juggalos это гораздо больше, чем просто белые рабочие мужчины.
#
# Источник [16]:
# И вот начинается руководство для худых парней по лучшему протеиновому порошку - окончательный рейтинг каждой встреченной мной добавки для наращивания мышц, оцененный по трем критериям
#
# Источник [17]:
# N-Large2 содержит 6 фунтов порошка для набора веса и является невероятным средством для набора веса для худых парней. Каждая порция обеспечивает ваше тело высококачественными белками, углеводами, подпитывающими энергией, и 600 здоровыми калориями для наращивания и сохранения мышечной массы. Каждая порция N-Large2 Mass Gainer содержит
#
# Источник [18]:
# Еще один продукт от того же бренда, но этот действительно мощный. Если вы худой парень, который пытается набрать вес, Serious Mass от Optimum Nutrition может добавить объема всего за несколько месяцев. Здесь есть пара "но". Первое
#
# Источник [19]:
# Использование качественных добавок, таких как N-Large2 Mass Gainer и BCAA Plus, может дать преимущество при наращивании мышечной массы для худых парней.
#
# Источник [20]:
# Говоря в общем, худым парням нужно цепляться за каждую возможную калорию. Но, если вы хотите сбросить вес и нарастить мышцы, Bulk Pure Whey Isolate 90 содержит 27 г белка на каждые 30 г порции, что делает его выбором с низким содержанием жиров и углеводов.
#
# Источник [21]:
# Оскорбления, связанные с сексом, распространены во многих различных культурах. Но обычно именно само ругательство, а не простое упоминание акта, считается провокационным. Использование слова "ебать" гораздо более оскорбительно, чем "заниматься любовью", например.
#
# Источник [22]:
# Ругательства происходят из того, что мы считаем табу или непристойным. В англоязычном обществе у нас много табу, связанных с сексом, даже в наше время. Мы также придаем очень большое значение гигиене, поэтому слова, связанные с отходами и их происхождением, также являются табу.
#
# Источник [23]:
# Часть причины, по которой слова становятся для нас табу, заключается в том, что мы усваиваем культурный контекст, делающий определенные концепции табуированными. Во многих культурах именно слова, относящиеся к женским гениталиям, считаются наиболее возмутительными; гораздо более, чем ругательства, относящиеся к мужской анатомии. Теоретизируется, что это потому, что мужская сексуальность обычно считалась приемлемой, в то время как женская сексуальность реже принималась и выражалась.
#
# Источник [24]:
# Несколько венесуэльских НПО, таких как Foro Penal, Súmate, Voto Joven [es], Венесуэльская избирательная обсерватория и Гражданская избирательная сеть выразили свою обеспокоенность по поводу нарушений избирательного графика, включая отсутствие полномочий Учредительного собрания для созыва выборов, препятствование участию оппозиционных политических партий и недостаток времени для стандартных избирательных функций. Из-за этого Европейский Союз, Организация американских государств, Лимская группа и страны, включая Австралию и Соединенные Штаты, отвергли избирательный процесс. Однако страны, включая Китай, Кубу, Иран, Россию, Сирию, Турцию и другие, признали результаты выборов.
#
# Источник [37]:
# Оппозиционное Движение за демократическое единство (или MUD по его испанскому аббревиатуре) одержало крупную победу над партиями, поддерживающими правительство, на законодательных выборах 6 декабря. Обновленные официальные результаты показывают 107 мест для MUD, 55 для правящей партии, 3 представляющих коренные сообщества, с 2 еще не решенными.
#
# Источник [38]:
# КАРАКАС, 22 ноября (Reuters) - Национальный избирательный совет (CNE) Венесуэлы присудил победу правящей Социалистической партии в 20 губернаторствах и трех - оппозиционным политикам в первом объявлении в понедельник после местных и региональных выборов.
#
# Источник [39]:
# Явка на выборах в Венесуэле составила 32 процента к 18
#
# Источник [40]:
# Он едва упомянул низкую явку и сказал, что полученные им 68 процентов голосов были самым высоким процентом для победителя на президентских выборах в Венесуэле, назвав это нокаутом.
#
# Источник [41]:
# Точка G находится на несколько сантиметров вдоль внутренней передней стенки влагалища — верхней стенки, если вы лежите на спине. "Это на несколько дюймов вверх, примерно на треть пути, хотя это различается у каждого человека," - сказала Дженнифер Берман, доктор медицины, уролог и специалист по женской сексуальной медицине в Центре благополучия женщин Берман в Беверли-Хиллзе, в интервью для Health.
#
# Источник [42]:
# Точка G, также называемая точкой Грэфенберга (по немецкому гинекологу Эрнсту Грэфенбергу), характеризуется как эрогенная зона влагалища, которая, когда стимулируется, может привести к сильному сексуальному возбуждению, мощным оргазмам и потенциальному женскому эякуляту. Обычно сообщается, что она находится на расстоянии 5–8 см (2–3 дюйма) вверх по передней (передней) стенке влагалища между влагалищным отверстием и уретрой и является чувствительной областью, которая может быть частью женской простаты.
#
# Источник [43]:
# Прежде всего, вам нужно знать, куда смотреть. "Точка G находится примерно в двух дюймах внутрь и в один дюйм вверх внутри влагалища," - говорит Тейлор Спаркс, эротический педагог и основатель OrganicLoven.com. "Но все женщины разные, и вам может потребоваться двигаться на один дюйм вверх и вправо или влево. Это потребует исследования и лучше всего делать это с помощью пальцев."
#
# Источник [44]:
# Эти результаты показывают, что другие факторы играют роль в том, сможет ли женщина найти точку G или определить конкретное место как свою точку G.
#
# Источник [45]:
# Область точки G находится внутри влагалища женщины, примерно на треть пути между влагалищным отверстием и шейкой матки. Это где-то между 1,5 и 3 дюймами внутри влагалища на верхней стенке, так что представьте себе небольшие часы внутри влагалища, и вы найдете точку G между 11 и 1 часом (с 12
#
# Источник [46]:
# Еще один способ, которым помещение металла в микроволновку может убить магнетрон, - это когда достаточное количество генерируемых микроволн не поглощается, что может произойти, если пища завернута в алюминиевую фольгу или в основном заключена в металлический контейнер. Если энергия не поглощается, ей некуда идти, кроме как обратно к магнетрону, чтобы повредить его, что, опять же, может сделать вашу микроволновку непригодной к использованию.
#
# Источник [47]:
# Это не значит, что металл не может нагреться; он может. Он содержит электроны, которые притягиваются к микроволнам тоже. Но без чего-то, что эффективно поглощает энергию, которую производит это притяжение (то есть, пищу), металл передает ее чему-то поблизости — а именно, внутренней электронике вашей печи, что приводит к перегреву и возможно к пожару.
#
# Источник [48]:
# Так безопасно ли использовать какой-либо металл в микроволновке? Ну, вы, возможно, не заметили, но в вашей микроволновке уже есть куча металла. Стены и электроника в основном металлические, а дверца имеет встроенную сетку, которая пропускает видимый свет, но отражает микроволны обратно. Это экранирование важно. Не только ваши остатки еды в основном состоят из воды, но и вы тоже, и было бы неприятно приготовить себя до того, как будет готов фаршированный перец. (Ожоги от микроволновки - это реальность, но если вы хотите экстремальных бедствий от микроволновки, обратитесь к вымыслу
#
# Источник [49]:
# Мы все слышали, что нельзя класть металл в микроволновку. Но на самом деле, мы часто кладем металлы в микроволновку — например, когда разогреваем Hot Pocket. Его пакетик имеет тонкий слой алюминиевой фольги, который предназначен для поглощения микроволн и немного нагревается, чтобы подрумянить внешнюю часть Hot Pocket.
#
# Источник [50]:
# Во-вторых, если металл, который вы кладете в микроволновку, заострен (как вилка), имеет острые углы (как смятая алюминиевая фольга) или тонкий (как декоративное золото на вашей фантазийной чашке), то электроны, перемещаемые микроволнами, могут собираться вдоль краев. Когда в одном месте накапливается слишком много заряда, эти электроны становятся очень недовольными. И недовольные электроны могут — цап! — прыгнуть через воздух, чтобы найти лучшее место. (Тот статический электрический удар, который вы получаете, перетаскиваясь по ковру и касаясь дверной ручки? То же самое.) Хотя небольшое количество искр между зубцами вилки, вероятно, не причинит долгосрочного ущерба, большие искры между металлом и корпусом - вот где начинаются проблемы. Бросьте немного бумаги или что-то легковоспламеняющееся туда, и апокалиптический прогноз вашей матери сбудется.
#
#
#
# ---
# # Инструкции:
#
# 1. Дай полный и краткий ответ на вопрос, используя только информацию из контекста.
# 2. Указывай источники, с которыми работаешь, например: [1].
# 3. Ответ должен содержать хотя бы одну ссылку на источник.
# 4. Ответ гарантированно содержится в указанных источниках.
# 5. Не используй знания вне предоставленного контекста.
#
# # Вопрос:
#
# В футболе в чем смысл тратить первые два хода на прорыв через центр, а не на обычные игры на прорыв, я понимаю их.
#
#
# Смысл тратить первые два хода на прорыв через центр заключается в использовании 40-секундного игрового таймера и двухминутного предупреждения в профессиональных и студенческих футбольных матчах. Атакующая сторона надеется, что сможет заблокировать всех защитников, и бегущий нападающий сможет обойти одного из игроков и в итоге оказаться в зоне вбивания мяча[7]. Прорыв через центр также является самым коротким путем к зоне вбивания мяча, поэтому он часто задумывается для того, чтобы убрать защитников с пути[8]. Кроме того, достаточное количество прорывов через центр заставит лайнбекеров и защитников бежать к линии скриммиджа, создавая идеальную возможность бросить мяч над их головами или в освободившиеся зоны[9]. Эта стратегия используется для того, чтобы как можно дольше удерживать мяч, а не пытаться забить[7][10].
