# %%
import re
import asyncio
import os
from dotenv import load_dotenv
from openai import AsyncOpenAI
from openai import OpenAI
from tqdm.asyncio import tqdm_asyncio
import json



MODEL_NAME_1 = "qwen-3b-raw"

MODEL_NAME_2 = "qwen-3b-raft"


JUDGE_NAME = "meta-llama/Llama-3.3-70B-Instruct"






def get_judge_prompt(question, relevant_context, reference_answer, model_answer_1, model_answer_2):
    messages = []

    messages.append({"role": "system", "content": "You are a helpful assistant that two side by side RAG answers against the ground truth. Always respond with a JSON object "
                                                "containing a 'comment' (string), 'winner' (number 0-2) fields."})

    judge_prompt = f"""
    **Question**: {question}

    **Relevant context**: {relevant_context}

    **Reference Answer**: {reference_answer}

    **Model Answer 1**: {model_answer_1}

    **Model Answer 2**: {model_answer_2}

    
    **Evaluation Rules**:
    - Compare Answer A and Answer B side by side against the reference.
    - Decide which is better overall, or state if they are equally good (if that so winner=0).
    - Briefly justify your choice (2–3 sentences)

    Provide analysis in JSON format: {{"comment": "...", "winner": 1-2}}"""

    messages.append({"role": "user", "content": judge_prompt})

    return messages

# %%
# import re
# import asyncio
# import os
# from dotenv import load_dotenv
# from openai import AsyncOpenAI
# from openai import OpenAI
# from tqdm.asyncio import tqdm_asyncio
# import json



# MODEL_NAME = "qwen-1.5b-ru"


# JUDGE_NAME = "meta-llama/Llama-3.3-70B-Instruct"





# REJECT_ANSW = "К сожалению, ответа на вопрос нет в упомянутых источниках"

# def get_judge_prompt(question, relevant_context, reference_answer, model_answer):
#     messages = []

#     messages.append({"role": "system", "content": "You are a helpful assistant that scores RAG answers against the ground truth. Always respond with a JSON object "
#                                                 "containing a 'comment' (string), 'is_inappropriate_refusal' (0-1), 'score' (number 1-5), 'is_correct' (0-1) fields."})

#     judge_prompt = f"""
#     **Question**: {question}
#     **Relevant context**: {relevant_context}
#     **Reference Answer**: {reference_answer}
#     **Model Answer**: {model_answer}

#     **Evaluation Rules**:
#     1. Scoring Scale:
#     - 5: Good answer (factually correct, complete)
#     - 4: Mostly correct with minor issues
#     - 3: Partially correct but has inaccuracies
#     - 2: Mostly incorrect but contains relevant elements
#     - 1: Completely wrong or irrelevant

#     2. Binary Correctness:
#     - 1 (Correct): Answer conveys the same meaning as reference (exact wording not required)
#     - 0 (Incorrect): Meaning differs from reference or contains false information

#     3. Binary Refuse:
#     - 1 (Inappropriate refusal): The model answer is a refusal, while the reference contains a full answer
#     - 0 (A normal answer or an appropriate refusal)

#     4. Key Principles:
#     - Focus on whether the model answers the question asked, not on whether it exactly matches the reference
#     - There is no need to lower the score if the model's answer omits some facts that are insignificant to the question
#     - If an answer seems redundant in relation to the reference, but the information is contained in a relevant context, then there is no need to lower the score for this
#     - Ignore stylistic differences if core meaning is preserved
#     - Inappropriate refusal should always have score 2 out of 5!

#     Provide analysis in JSON format: {{"comment": "...", "score": 1-5, "is_correct": 0|1, "is_inappropriate_refusal": 0|1}}"""

#     messages.append({"role": "user", "content": judge_prompt})

#     return messages

# %%
load_dotenv()
API_KEY = os.getenv("NEBIUS_API_KEY")

# client = OpenAI(
#     base_url="https://api.studio.nebius.com/v1/",
#     api_key=API_KEY
# )

client = AsyncOpenAI(
    base_url="https://api.studio.nebius.com/v1/",
    api_key=API_KEY
)

# %%
# with open("generation/qwen-1.5b-raw.json", "r") as f:
#     benchmark_data = json.load(f)
#     data=benchmark_data[1]

# messages = get_judge_prompt(
#     data['table_data']['Вопрос'],
#     data['table_data']['Отрывок из документа'],
#     data['table_data']['Ответ'],
#     data['model_answer']
# )

# response = client.chat.completions.create(
#     model="deepseek-ai/DeepSeek-V3",
#     messages=messages, 
#     temperature=0.5,
#     max_completion_tokens=512
# )

# print(response.choices[0].message.content)
# Out:
# {"comment": "The model answer does not accurately address the question about the percentage of difficult-to-extract oil in Russia and its locations. Instead, it provides unrelated information about the total reserves and types of oil in different regions, without mentioning the specific percentage of difficult-to-extract oil or its primary locations as stated in the reference answer.", "score": 1, "is_correct": 0, "is_inappropriate_refusal": 0}

# %%
async def run_llm(messages : str, model : str, semaphore : asyncio.Semaphore):
    async with semaphore:
        return await client.chat.completions.create(
            model=model,
            messages=messages, 
            temperature=0.5,
            max_completion_tokens=512
        )
    

async def process_task(task_id, messages, model, semaphore):
    try:
        response = await run_llm(
            messages=messages,
            model=model,
            semaphore=semaphore,
        )
        return {
            "task_id": task_id,
            "content": response.choices[0].message.content,
            "status": "success"
        }
    except Exception as e:
        return {
            "task_id": task_id,
            "error": str(e),
            "status": "failed"
        }

# %%
semaphore = asyncio.Semaphore(50)

with open(f"generation/{MODEL_NAME_1}.json", "r") as f:
    benchmark_data_1 = json.load(f)

with open(f"generation/{MODEL_NAME_2}.json", "r") as f:
    benchmark_data_2 = json.load(f)    

tasks = [process_task(
    task_id=i,
    messages=get_judge_prompt(benchmark_data_1[i]['table_data']['Вопрос'], benchmark_data_1[i]['table_data']['Отрывок из документа'], 
                              benchmark_data_1[i]['table_data']['Ответ'], benchmark_data_1[i]['model_answer'], benchmark_data_2[i]['model_answer']),
    model=JUDGE_NAME,
    semaphore=semaphore)
    for i in range(len(benchmark_data_1))
]

results = []
with tqdm_asyncio(total=len(tasks), desc="Processing LLM requests") as pbar:
    for coro in asyncio.as_completed(tasks):
        result = await coro
        results.append(result)
        pbar.update(1)
# Out:
# Processing LLM requests: 100%|██████████| 674/674 [00:54<00:00, 12.38it/s]

# %%
results.sort(key=lambda x: x['task_id'])

for result in results:
    if result['status'] == "failed":
        print(result['task_id'])

# %%
def parse(content):
    json_str = re.search(r'\{.*?\}', content, re.DOTALL)

    result = json.loads(json_str.group(0))

    keys = ['comment', 'winner']

    # keys = ['comment', 'score', 'is_correct', 'is_inappropriate_refusal']

    judgment = {}
    for key in keys:
        if key in result:
            judgment[key] = result[key]
        else:
            judgment[key] = None

    return judgment


for i, data in enumerate(benchmark_data_1):
    try:
        data["judgment"] = parse(results[i]['content'])
    except:
        print(data)

with open(f"scored_sbs/{MODEL_NAME_1}-vs-{MODEL_NAME_2}.json", "w") as f:
    json.dump(benchmark_data_1, f, ensure_ascii=False, indent=2)
# Out:
# {'table_data': {'Домен документов': 'Техническая документация', 'Сет документов': 'linux', 'Название документа': 'linux.pdf', 'Отрывок из документа': 'Таблица 3.2. Подкаталоги корневого каталога\n\nДиректория\tСодержимое\n/bin\tОбщие программы для совместного использования системой, системным администратором и пользователями.\n/boot\tЗагрузочные файлы и ядро, vmlinuz. В некоторых дистрибутивах также данные grub – загрузчика.\n/dev\tСодержит ссылки на все периферийные устройства, представленные файлами с особыми свойствами.\n/etc\tБольшинство важных системных файлов конфигурации, аналогично Панели Управления Windows.\n/home\tДомашние каталоги обычных пользователей.\n/initrd\tИнформация для загрузки (в некоторых дистрибутивах). Не удаляйте!\n/lib\tФайлы библиотек, необходимые системе и пользователям.\n/lost+found\tФайлы, спасенные во время сбоев (присутствует в каждом разделе).\n/misc\tДля разных целей.\n/mnt\tСтандартные точки монтирования для внешних файловых систем.\n/net\tСтандартные точки монтирования для удаленных файловых систем.\n/opt\tДополнительное ПО и ПО третьих сторон.\n/proc\tВиртуальная файловая система, содержащая информацию о системных ресурсах.\n/root\tДомашняя директория администратора (не путать с корневым каталогом /).\n/sbin\tПрограммы для использования системой и системным администратором.\n/tmp\tВременное место, очищаемое после перезагрузки.\n/usr\tПрограммы, библиотеки, документация для всех пользовательских программ.\n/var\tИзменяемые и временные файлы (логи, почтовые очереди, print spooler и др.).\n', 'Тип вопроса': 'Table', 'Вопрос': 'Какая директория предназначена для хранения системных конфигурационных файлов, и чем она аналогична в Windows?\n\n', 'Ответ': 'Директория /etc содержит большинство важных системных файлов конфигурации, аналогично Панели Управления Windows.'}, 'context': [{'score': 0.8367969989776611, 'doc': 'linux', 'text': '| Директория   | Содержимое                                                                                                                                                                                                                                      |\n|--------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|\n| /bin         | Общие программы для совместного использования системой, системным администратором и пользователями.                                                                                                                                             |\n| /boot        | Загрузочные файлы и ядро, vmlinuz. В некоторых последних дистрибутивах также данные grub. Grub - это большой единый загрузчик, который представляет собой попытку избавиться от многих различных загрузчиков известных нам на сегодняшний день. |\n| /dev         | Содержит ссылки на все периферийные устройства, которые представлены файлами с особыми свойствами.                                                                                                                                              |\n| /etc         | Большинство важных системных файлов конфигурации находятся в /etc, этот каталог содержит данные, аналогичные тем что в Панели Управления Windows                                                                                                |\n| /home        | Домашние каталоги обычных пользователей.                                                                                                                                                                                                        |\n| /initrd      | (в некоторых дистрибутивах) Информация для загрузки. Не удаляйте!                                                                                                                                                                               |\n| /lib         | Файлы  ...

# %%
# with open("scored/qwen-1.5b-raw.json", "r") as raw, \
#      open("scored/qwen-1.5b-baseline.json", "r") as baseline:
#     raw = json.load(raw)[0:20]
#     baseline = json.load(baseline)[0:20]

#     avg_raw = 0
#     avg_baseline = 0

#     for i in range(20):
#         print("-----------------------------------------------------------------\n")
#         print(f"Question: {raw[i]['table_data']['Вопрос']}\n")
#         print(f"Relevant context: {raw[i]['table_data']['Отрывок из документа']}\n")
#         print(f"Reference answer: {raw[i]['table_data']['Ответ']}\n")
#         print(f"RAW answer: {raw[i]['model_answer']}\n")
#         print(f"RAW judgment: {raw[i]['judgment']}\n")
#         print(f"BASELINE answer: {baseline[i]['model_answer']}\n")
#         print(f"BASELINE judgment: {baseline[i]['judgment']}\n")
#         print("-----------------------------------------------------------------\n")

#         avg_raw += raw[i]["judgment"]["score"]
#         avg_baseline += baseline[i]["judgment"]["score"]

#     print("\n\n\n")
#     print(f"RAW avg score: {avg_raw / 20}")
#     print(f"BASELINE avg score: {avg_baseline / 20}")
# Out:
# -----------------------------------------------------------------
#
# Question: Какова доля трудноизвлекаемых запасов нефти в России и где расположены основные месторождения?
#
# Relevant context: Характерной особенностью современной мировой нефтедобычи является
# увеличение в структуре запасов доли трудноизвлекаемых нефтей (с вязкостью 30мПа и
# выше). Во многих промышленно развитых странах мира тяжелая нефть рассматривается
# в качестве основной базы развития нефтедобычи на ближайшие годы. Россия также
# обладает значительными ресурсами трудноизвлекаемых запасов, их объем составляет
# около 55 % от общих запасов российской нефти. Основные российские месторождения
# высоковязкой нефти расположены в Пермской области, Татарстане, Башкирии и
# Удмуртии. Наиболее крупные из них: Ван-Еганское, Северо-Комсомольское, Усинское,
# Русское, Гремихинское и др., при этом более 2/3 всех запасов высоковязкой нефти
# находятся на глубинах до 2000 м. На сегодня добыча высоковязкой нефти,
# транспортировка ее к пунктам сбора и подготовки и, наконец, переработка с целью
# получения конечных продуктов – одна из актуальных задач нефтедобывающей
# промышленности в связи с ростом доли трудноизвлекаемых запасов нефти в стране
#
# Reference answer: Доля трудноизвлекаемых запасов нефти в России составляет около 55 % от общих запасов российской нефти. Основные месторождения высоковязкой (трудноизвлекаемой) нефти расположены в Пермской области, Татарстане, Башкирии и Удмуртии.
#
# RAW answer: Доля трудноизвлекаемых запасов нефти в России составляет около 55%. Основные российские месторождения высоковязкой нефти расположены в Пермской области, Татарстане, Башкирии и Удмуртии. Наиболее крупные из них: Ван Еганское, Северо Комсомольское, Усинское, Русское, Гремихинское и др., при этом более 2/3 всех запасов высоковязкой нефти находятся на глубинах до 2000 м.
#
# RAW judgment: {'comment': 'The model answer is factually correct and complete, matching the reference answer in terms of the percentage of hard-to-recover oil reserves and the locations of the main fields. It also includes additional details about the largest fields and the depth of reserves, which are relevant and do not detract from the correctness. The answer is not a refusal and is appropriate.', 'score': 5, 'is_correct': 1, 'is_inappropriate_refusal': 0}
#
# BASELINE answer: Основные месторождения трудноизвлекаемых запасов нефти расположены в Пермской области, Татарстане, Башкирии и Удмуртии. Они занимают около 55% от общих запасов российской нефти. Большая часть этих запасов находится на глубинах до 2000 метров.
#
# BASELINE judgment: {'comment': 'The model answer correctly identifies the location of the main deposits of hard-to-recover oil in Russia and mentions the proportion of these reserves (55%). However, it incorrectly states that these deposits occupy 55% of the total reserves, which is a misinterpretation of the context. The context clearly states that the volume of hard-to-recover reserves is about 55% of the total reserves, not that the deposits themselves occupy this percentage. This inaccuracy affects the correctness of the answer.', 'score': 3, 'is_correct': 0, 'is_inappropriate_refusal': 0}
#
# -----------------------------------------------------------------
#
# -----------------------------------------------------------------
#
# Question: Сколька процента нефти в России трудано достать и гдзе ана?
#
# Relevant context: Характерной особенностью современной мировой нефтедобычи является
# увеличение в структуре запасов доли трудноизвлекаемых нефтей (с вязкостью 30мПа и
# выше). Во многих промышленно развитых странах мира тяжелая нефть рассматривается
# в качестве основной базы развития нефтедобычи на ближайшие годы. Россия также
# обладает значительными ресурсами трудноизвлекаемых запасов, их объем составляет
# около 55 % от общих запасов российской нефти. Основные российские месторождения
# высоковязкой нефти расположены в Пермской области, Татарстане, Башкирии и
# Удмуртии. Наиболее крупные из них: Ван-Еганское, Северо-Комсомольское, Усинское,
# Русское, Гремихинское и др., при этом более 2/3 всех запасов высоковязкой нефти
# находятся на глубинах до 2000 м. На сегодня добыча высоковязкой нефти,
# транспортировка ее к пунктам сбора и подготовки и, наконец, переработка с целью
# получения конечных продуктов – одна из актуальных задач нефтедобывающей
# промышленности в связи с ростом доли трудноизвлекаемых запасов нефти в стране
#
# Reference answer: Доля трудноизвлекаемых запасов нефти в России составляет около 55 % от общих запасов российской нефти. Основные месторождения высоковязкой (трудноизвлекаемой) нефти расположены в Пермской области, Татарстане, Башкирии и Удмуртии.
#
# RAW answer: По данным источников, около 55% российских нефтяных месторождений имеют трудноизвлекаемые запасы нефти, что делает их труднее вывести на поверхность.
#
# RAW judgment: {'comment': 'The model answer correctly states that about 55% of Russian oil reserves are hard to extract, which matches the reference answer. However, it omits the specific locations of these reserves, which are a key part of the reference answer. This omission makes the answer incomplete but not incorrect.', 'score': 4, 'is_correct': 1, 'is_inappropriate_refusal': 0}
#
# BASELINE answer: Существует около 90% всех запасов нефти в России, что делает Россию одной из крупнейших держателей запасов нефти в мире. Большая часть нефти 1 типа, по плотности, сосредоточена в Лено-Вилюйской и Охотской нефтегазоносных провинциях, а меньше всего в Волго-Уральской нефтегазоносной провинции.
#
# BASELINE judgment: {'comment': 'The model answer is incorrect as it states that 90% of all oil reserves in Russia are hard to extract, which contradicts the reference answer stating that 55% are hard to extract. Additionally, the model answer incorrectly identifies the locations of the oil reserves, mentioning Leno-Vilyui and Okhotsk oil and gas provinces instead of Perm, Tatarstan, Bashkiria, and Udmurtia as stated in the reference. The model answer does not address the question accurately and provides misleading information.', 'score': 1, 'is_correct': 0, 'is_inappropriate_refusal': 0}
#
# -----------------------------------------------------------------
#
# -----------------------------------------------------------------
#
# Question: Привет, у меня тут возник вопрос по поводу сложностей нефтедобычи. Знаешь, я слышал, что в России много нефти, но насколько реально её добывать? Наверное большую часть очень сложно добывать, да?!? Особенно интересует, какая часть этой нефти считается трудноизвлекаемой и где её больше всего? Спасибо заранее!
#
# Relevant context: Характерной особенностью современной мировой нефтедобычи является
# увеличение в структуре запасов доли трудноизвлекаемых нефтей (с вязкостью 30мПа и
# выше). Во многих промышленно развитых странах мира тяжелая нефть рассматривается
# в качестве основной базы развития нефтедобычи на ближайшие годы. Россия также
# обладает значительными ресурсами трудноизвлекаемых запасов, их объем составляет
# около 55 % от общих запасов российской нефти. Основные российские месторождения
# высоковязкой нефти расположены в Пермской области, Татарстане, Башкирии и
# Удмуртии. Наиболее крупные из них: Ван-Еганское, Северо-Комсомольское, Усинское,
# Русское, Гремихинское и др., при этом более 2/3 всех запасов высоковязкой нефти
# находятся на глубинах до 2000 м. На сегодня добыча высоковязкой нефти,
# транспортировка ее к пунктам сбора и подготовки и, наконец, переработка с целью
# получения конечных продуктов – одна из актуальных задач нефтедобывающей
# промышленности в связи с ростом доли трудноизвлекаемых запасов нефти в стране
#
# Reference answer: Доля трудноизвлекаемых запасов нефти в России составляет около 55 % от общих запасов российской нефти. Основные месторождения высоковязкой (трудноизвлекаемой) нефти расположены в Пермской области, Татарстане, Башкирии и Удмуртии.
#
# RAW answer: К сожалению, ответа на вопрос нет в упомянутых источниках.
#
# RAW judgment: {'comment': 'The model answer is an inappropriate refusal, as the relevant context clearly contains the information needed to answer the question. The reference answer correctly states that 55% of Russian oil reserves are hard-to-recover and lists the main regions where such oil is found. The model fails to provide this information despite it being available in the context.', 'score': 2, 'is_correct': 0, 'is_inappropriate_refusal': 1}
#
# BASELINE answer: Добыча нефти в России представляет собой сложный процесс, который требует использования мощного и массивного оборудования и специальных технологических процессов для преобразования нефти в нефтепродукты. Большинство нефти добывают на месторождениях Западно-Сибирского НГБ, находящихся на стадии падающей добычи, и другие нефтедобывающие регионы страны далеко не так продуктивны. Кроме того, добыча нефти в Арктике осложнена сложными климатическими и природными условиями района добычи, а также технологической сложностью освоения.
#
# BASELINE judgment: {'comment': 'The model answer does not address the specific question about the proportion of hard-to-recover oil reserves in Russia or their main locations. Instead, it discusses general challenges of oil extraction in different regions, which is not relevant to the query. The answer lacks the key information provided in the reference answer.', 'score': 1, 'is_correct': 0, 'is_inappropriate_refusal': 0}
#
# -----------------------------------------------------------------
#
# -----------------------------------------------------------------
#
# Question: Какой процент российских нефтяных ресурсов представляет собой трудноизвлекаемые месторождения, и в каких регионах они преимущественно сосредоточены?
#
# Relevant context: Характерной особенностью современной мировой нефтедобычи является
# увеличение в структуре запасов доли трудноизвлекаемых нефтей (с вязкостью 30мПа и
# выше). Во многих промышленно развитых странах мира тяжелая нефть рассматривается
# в качестве основной базы развития нефтедобычи на ближайшие годы. Россия также
# обладает значительными ресурсами трудноизвлекаемых запасов, их объем составляет
# около 55 % от общих запасов российской нефти. Основные российские месторождения
# высоковязкой нефти расположены в Пермской области, Татарстане, Башкирии и
# Удмуртии. Наиболее крупные из них: Ван-Еганское, Северо-Комсомольское, Усинское,
# Русское, Гремихинское и др., при этом более 2/3 всех запасов высоковязкой нефти
# находятся на глубинах до 2000 м. На сегодня добыча высоковязкой нефти,
# транспортировка ее к пунктам сбора и подготовки и, наконец, переработка с целью
# получения конечных продуктов – одна из актуальных задач нефтедобывающей
# промышленности в связи с ростом доли трудноизвлекаемых запасов нефти в стране
#
# Reference answer: Доля трудноизвлекаемых запасов нефти в России составляет около 55 % от общих запасов российской нефти. Основные месторождения высоковязкой нефти расположены в Пермской области, Татарстане, Башкирии и Удмуртии.
#
# RAW answer: По данным источника [1], трудноизвлекаемые нефтяные ресурсы занимают около 55% от общих запасов российской нефти. Эти ресурсы преимущественно сосредоточены в Пермской области, Татарстане, Башкирии и Удмуртии.
#
# RAW judgment: {'comment': 'The model answer accurately reflects the information provided in the reference answer, stating that 55% of Russian oil reserves are hard-to-recover and listing the correct regions where these resources are concentrated. The answer is factually correct and complete.', 'score': 5, 'is_correct': 1, 'is_inappropriate_refusal': 0}
#
# BASELINE answer: Примерно 55% российских нефтяных ресурсов представлены трудноизвлекаемыми месторождениями, которые имеют вязкость 30мПа и выше. Они преимущественно сосредоточены в Пермской области, Татарстане, Башкирии и Удмуртии.
#
# BASELINE judgment: {'comment': 'The model answer is factually correct and complete, matching the reference answer in terms of the percentage of difficult-to-extract oil reserves and their primary locations. The additional detail about the viscosity (30мПа и выше) adds value without detracting from the core information.', 'score': 5, 'is_correct': 1, 'is_inappropriate_refusal': 0}
#
# -----------------------------------------------------------------
#
# -----------------------------------------------------------------
#
# Question: В России практически нет трудноизвлекаемых запасов нефти, и основные месторождения высоковязкой нефти находятся на Крайнем Севере. Это правда?
#
# Relevant context: Характерной особенностью современной мировой нефтедобычи является
# увеличение в структуре запасов доли трудноизвлекаемых нефтей (с вязкостью 30мПа и
# выше). Во многих промышленно развитых странах мира тяжелая нефть рассматривается
# в качестве основной базы развития нефтедобычи на ближайшие годы. Россия также
# обладает значительными ресурсами трудноизвлекаемых запасов, их объем составляет
# около 55 % от общих запасов российской нефти. Основные российские месторождения
# высоковязкой нефти расположены в Пермской области, Татарстане, Башкирии и
# Удмуртии. Наиболее крупные из них: Ван-Еганское, Северо-Комсомольское, Усинское,
# Русское, Гремихинское и др., при этом более 2/3 всех запасов высоковязкой нефти
# находятся на глубинах до 2000 м. На сегодня добыча высоковязкой нефти,
# транспортировка ее к пунктам сбора и подготовки и, наконец, переработка с целью
# получения конечных продуктов – одна из актуальных задач нефтедобывающей
# промышленности в связи с ростом доли трудноизвлекаемых запасов нефти в стране
#
# Reference answer: Нет, это неверно. В России трудноизвлекаемые запасы нефти составляют около 55 % от общих запасов. Основные месторождения высоковязкой нефти расположены в Пермской области, Татарстане, Башкирии и Удмуртии.
#
# RAW answer: К сожалению, ответа на вопрос нет в упомянутых источниках.
#
# RAW judgment: {'comment': 'The model answer is an inappropriate refusal, as the relevant context clearly contains the information needed to answer the question. The reference answer correctly states that Russia has significant resources of hard-to-recover oil, and the main deposits are located in specific regions, not just in the Far North.', 'score': 2, 'is_correct': 0, 'is_inappropriate_refusal': 1}
#
# BASELINE answer: Нет, фактически, в России есть много трудноизвлекаемых запасов нефти, особенно в Пермской области, Татарстане, Башкирии и Удмуртии. Однако основные месторождения высоковязкой нефти находятся на глубинах до 2000 метров, и большая часть этих месторождений находится на Крайнем Севере.
#
# BASELINE judgment: {'comment': 'The model answer correctly states that Russia has significant reserves of hard-to-extract oil and mentions the regions where these reserves are located. However, it incorrectly asserts that the majority of these reserves are in the Far North, which contradicts the context provided. This inaccuracy affects the factual correctness of the answer.', 'score': 2, 'is_correct': 0, 'is_inappropriate_refusal': 0}
#
# -----------------------------------------------------------------
#
# -----------------------------------------------------------------
#
# Question: Какие допустимые значения массовой концентрации хлористых солей установлены для нефти первой группы согласно ГОСТ Р 51858-2002?
#
# Relevant context: Обезвоженная, обессоленная и стабилизированная нефть, поставляемая
# потребителю, согласно ГОСТ Р 51858-2002 подразделяется на три группы. При этом в
# каждой из групп содержание воды не должно превышать 0,5 % масс., 0,5 % масс. и 1,0 %
# масс., содержание хлористых солей не должно превышать 100, 300 и 900 мг/дм3
# соответственно, а механических примесей должно быть не более 0,05 % масс (таблица
# 2.6).
#
# Таблица 2.6 – Группы нефтей
#                                  Норма для нефти
#  Наименование показателя             группы                  Методы испытания
#                                  1      2      3
#  Массовая доля воды, %, не                                По ГОСТ 2477 и 9.5
#                                  0,5      0,5       1,0
#  более                                                    настоящего стандарта
#  Массовая концентрация
#                                                           По ГОСТ 21534 и 9.6
#  хлористых солей, мг/дм3, не     100      300       900
#                                                           настоящего стандарта
#  более
#  Массовая доля
#  механических примесей, %,               0,05             По ГОСТ 6370
#  не более
#  Давление насыщенных                                      По ГОСТ 1756, ГОСТ Р
#  паров, кПа (мм рт. ст.), не           66,7 (500)         52340 и 9.8 настоящего
#  более                                                    стандарта
#  Массовая доля органических
#  хлоридов во фракции,                                     По ГОСТ Р 52247 или
#                                  10       10        10
#  выкипающей до температуры                                приложению А (6)
#  204 °С, млн-1 (ррm), не более
#
# Reference answer: Не более 100 мг/дм³.
#
# RAW answer: Допустимая массовая концентрация хлористых солей для нефти первой группы составляет не более 900 мг/дм³.
#
# RAW judgment: {'comment': 'The model answer incorrectly states that the permissible mass concentration of chloride salts for the first group of oil is not more than 900 mg/dm³, whereas the correct value according to GOST R 51858-2002 is not more than 100 mg/dm³. This is a significant factual error.', 'score': 1, 'is_correct': 0, 'is_inappropriate_refusal': 0}
#
# BASELINE answer: Массовая концентрация хлористых солей, мг/дм³, не более 100 мг/дм³ для нефти первой группы согласно ГОСТ Р 51858-2002.
#
# BASELINE judgment: {'comment': 'The model answer is factually correct and matches the reference answer in meaning, stating that the mass concentration of chloride salts for the first group of oil should not exceed 100 mg/dm³ according to GOST R 51858-2002. The answer is complete and accurate, though slightly more verbose than the reference.', 'score': 5, 'is_correct': 1, 'is_inappropriate_refusal': 0}
#
# -----------------------------------------------------------------
#
# -----------------------------------------------------------------
#
# Question: Каково максимальное допустимое содержание механических примесей в нефти, поставляемой потребителю, согласно ГОСТ Р 51858-2002?
#
# Relevant context: Обезвоженная, обессоленная и стабилизированная нефть, поставляемая
# потребителю, согласно ГОСТ Р 51858-2002 подразделяется на три группы. При этом в
# каждой из групп содержание воды не должно превышать 0,5 % масс., 0,5 % масс. и 1,0 %
# масс., содержание хлористых солей не должно превышать 100, 300 и 900 мг/дм3
# соответственно, а механических примесей должно быть не более 0,05 % масс (таблица
# 2.6).
#
# Таблица 2.6 – Группы нефтей
#                                  Норма для нефти
#  Наименование показателя             группы                  Методы испытания
#                                  1      2      3
#  Массовая доля воды, %, не                                По ГОСТ 2477 и 9.5
#                                  0,5      0,5       1,0
#  более                                                    настоящего стандарта
#  Массовая концентрация
#                                                           По ГОСТ 21534 и 9.6
#  хлористых солей, мг/дм3, не     100      300       900
#                                                           настоящего стандарта
#  более
#  Массовая доля
#  механических примесей, %,               0,05             По ГОСТ 6370
#  не более
#  Давление насыщенных                                      По ГОСТ 1756, ГОСТ Р
#  паров, кПа (мм рт. ст.), не           66,7 (500)         52340 и 9.8 настоящего
#  более                                                    стандарта
#  Массовая доля органических
#  хлоридов во фракции,                                     По ГОСТ Р 52247 или
#                                  10       10        10
#  выкипающей до температуры                                приложению А (6)
#  204 °С, млн-1 (ррm), не более
#
# Reference answer: Не более 0,05 % масс.
#
# RAW answer: Максимальное допустимое содержание механических примесей в нефти, поставляемой потребителю, согласно ГОСТ Р 51858-2002, составляет 1,0% массы.
#
# RAW judgment: {'comment': 'The model answer incorrectly states that the maximum allowable content of mechanical impurities is 1.0% mass, whereas the correct value, as per the reference, is 0.05% mass. This significant inaccuracy affects the factual correctness of the answer.', 'score': 1, 'is_correct': 0, 'is_inappropriate_refusal': 0}
#
# BASELINE answer: Максимальное допустимое содержание механических примесей в нефти, поставляемой потребителю, согласно ГОСТ Р 51858-2002, составляет 0,05% массы.
#
# BASELINE judgment: {'comment': 'The model answer is factually correct and matches the reference answer in terms of content and meaning. The wording is slightly different but conveys the same information accurately.', 'score': 5, 'is_correct': 1, 'is_inappropriate_refusal': 0}
#
# -----------------------------------------------------------------
#
# -----------------------------------------------------------------
#
# Question: Какие методы применялись для поиска нефтегазовых месторождений в Удмуртии?
#
# Relevant context: nan
#
# Reference answer: В документах нет информации для ответа на этот вопрос.
#
# RAW answer: К сожалению, ответа на вопрос нет в упомянутых источниках.
#
# RAW judgment: {'comment': 'The model correctly states that the answer is not available in the mentioned sources, which aligns with the reference answer. This is an appropriate refusal as there is no information to provide.', 'score': 5, 'is_correct': 1, 'is_inappropriate_refusal': 0}
#
# BASELINE answer: Методы, используемые для поиска нефтегазовых месторождений в Удмуртии, включают в себя бурение скважин, проведение геологических исследований, использование геофизических методов, такие как геолокализация, и создание модели картографической информации. Кроме того, используются различные методы, такие как гидравлические модели, чтобы оценить эффективность применения методов и рекомендовать объемы их применения.
#
# BASELINE judgment: {'comment': 'The model answer provides detailed methods for searching oil and gas fields, which is not supported by the reference answer stating that there is no information available in the documents. This discrepancy makes the model answer incorrect as it introduces information not validated by the reference.', 'score': 1, 'is_correct': 0, 'is_inappropriate_refusal': 0}
#
# -----------------------------------------------------------------
#
# -----------------------------------------------------------------
#
# Question: Опиши способы повышения эффективности транспортировки нефти и газа, а также систем охлаждения для нефтедобывающего комплекса.
#
# Relevant context: 5.7   Система охлаждения
#
# НДТ 7. Применение воздушной системы охлаждения
#
#       Описание
#       Подробное описание систем воздушного охлаждения представлено в
# горизонтальном справочнике НДТ ИТС 20–2016 “Промышленные системы
# охлаждения”. Применение воздушной системы охлаждения вместо водной позволяет
# снизить экологические воздействия и повысить экономическую эффективность
# процесса.
#
# 5.12. Транспортирование нефти и газа
#
# НДТ 16. Применение труб повышенной надёжности
#       Описание
#       Повышение коррозионной активности транспортируемой жидкости по
# нефтепромысловым        трубопроводам      является    актуальной     проблемой
# нефтедобывающих       предприятий,     препятствующей     эффективной     работе
# трубопроводного транспорта и приводящей к аварийным ситуациям. Коррозионные
# разрушения, отложения парафинов и солей приводили к остановкам эксплуатации
# трубопроводов. Внедрение труб повышенной надежности позволяет снизить
# аварийность при транспортировке нефти.
#
#  НДТ 17. Ингибиторная защита
#       Описание
#       Увеличение коррозионной активности добываемой совместно с нефтью воды
# при разработке месторождений с повышенной обводненностью нефти является
# серьезной проблемой. Технология применения ингибиторов коррозии позволяет
# снизить агрессивность добываемых сред, а также предотвращения активного контакта
# металлической поверхности с окружающей средой. На металле образуется пленка,
# которая существенно ограничивает площадь контакта поверхности с коррозионной
# средой и служит надежным барьером, препятствующим протеканию процессов
# саморастворения.
#
# НДТ 18. Подавление жизнедеятельности сульфатвосстанавливающих
# бактерий
#       Описание
#       Одной из причин, приводящих к разрушению нефтепромыслового оборудования
# и коммуникаций от коррозии, является жизнедеятельность микроорганизмов, в
# частности сульфатвосстанавливающих бактерий (СВБ). Применение бактерицидов в
# системе “Пласт-скважина-узел закачки воды” позволяет подавить СВБ.
#
# Reference answer: Согласно ИТС-28-2017 существует несколько наилучших доступных технологий в этих разделах.
#
# Траспортирование нефти и газа:
# 1) Применение труб повышенной надёжности.
# 2) Ингибиторная защита.
# 3) Подавление жизнедеятельности сульфатвосстанавливающих бактерий.
#
# Система охлаждения:
# Применение воздушной системы охлаждения вместо водной.
#
# RAW answer: ### Способы повышения эффективности транспортировки нефти и газа:
#
# 1. **Центробежные насосы**: Эти устройства обеспечивают высокую производительность и могут значительно улучшить способность транспортировки нефти и газа.
# 2. **Объемные насосы**: Они позволяют транспортировать большие объемы нефти и газа, что особенно важно для крупных нефтедобывающих комплексов.
# 3. **Энергоэффективные технологии**: Это может включать использование современных энергоэффективных систем охлаждения и других технологий, которые помогают минимизировать能耗 и повысить производительность.
#
# ### Системы охлаждения для нефтедобывающего комплекса:
#
# 1. **Водный охлаждение**: Используется для охлаждения технологического оборудования и рабочих сред, чтобы предотвратить перегрев и сохранить безопасность.
# 2. **Аэродинамическое охлаждение**: Этот метод применяется для охлаждения газа, чтобы предотвратить его перегрев и сохранить его качество.
# 3. **Теплообменники**: Используются для передачи тепла от одного объекта к другому, что позволяет использовать энергию в различных областях нефтедобывающего комплекса.
# 4. **Холодильные установки**: Используются для хранения продуктов и сырья, предотвращая их перегрев и сохраняя их качество.
#
# ### Особенности системы охлаждения:
#
# - **Системы охлаждения** используются для охлаждения технологического оборудования и рабочих сред, чтобы предотвратить перегрев и сохранить безопасность.
# - **Основные загрязняющие веществ**, которые могут вызвать проблемы, это **углеводороды**.
# - **Загрязнители** в системах охлаждения обычно **углеводороды**.
# - **Таблица 3.124** показывает влияние охлаждающих систем на окружающую среду.
# - **Таблица 36** описывает
#
# RAW judgment: {'comment': 'The model answer does not align with the reference answer. It introduces concepts like centrifugal pumps, volumetric pumps, and energy-efficient technologies, which are not mentioned in the relevant context or reference answer. Additionally, it incorrectly lists water cooling as a method for cooling systems, whereas the reference specifically recommends air cooling. The model answer also includes irrelevant details about cooling systems and tables that are not pertinent to the question. Overall, the answer is factually incorrect and lacks the specific technologies mentioned in the reference.', 'score': 1, 'is_correct': 0, 'is_inappropriate_refusal': 0}
#
# BASELINE answer: Существует несколько способов повышения эффективности транспортировки нефти и газа, включая использование различных систем охлаждения для нефтедобывающих комплексов. одним из наиболее распространенных методов является использование систем водного охлаждения, которые используют воду, предварительно подготовленную химическими веществами, такие как ингибиторы роста коррозии и бактерий. другие методы включают использование систем воздушного охлаждения, где используется воздух вместо воды, и использование тепловых насосов для поддержания пластового давления. также важны системы поддержания пластового давления, которые обеспечивают постоянное давление в трубопроводах, что важно для сохранения высокой производительности.
#
# BASELINE judgment: {'comment': 'The model answer contains inaccuracies and irrelevant information. It incorrectly mentions the use of water cooling systems, which is not supported by the context. Additionally, it introduces unrelated concepts like thermal pumps and maintaining reservoir pressure, which are not mentioned in the reference. The correct methods for improving transportation efficiency and cooling systems are either missing or misrepresented.', 'score': 2, 'is_correct': 0, 'is_inappropriate_refusal': 0}
#
# -----------------------------------------------------------------
#
# -----------------------------------------------------------------
#
# Question: Может ли технология нефтедобычи быть признанной наилучшей доступной технологией (НДТ), если среди членов технических рабочих групп (ТРГ) нет единогласного согласия?
#
# Relevant context: Шаг 6. Принятие членами ТРГ решения об отнесении технологии к НДТ
#       Технология нефтедобычи может быть определена в качестве НДТ при
# достижении соглашения между всеми членами ТРГ по данному вопросу. При
# возникновении различных мнений в ТРГ по какому-либо вопросу федеральным
# органом исполнительной власти, ответственным за разработку информационно-
# технических справочников НДТ, может быть предложено компромиссное решение. При
# возникновении серьезных разногласий относительно того, какие технологии
# определить в качестве НДТ, может быть проведена более углубленная комплексная
# оценка технологий.
#       Окончательное решение о выборе технологии принимают не только с учетом ее
# «экологичности», но и с учетом ее доступности с финансовой точки зрения.
# При наличии особого мнения по определению технологии нефтедобычи в
# качестве НДТ, не поддерживаемого всеми членами ТРГ, такая технология может быть
# определена в качестве НДТ и включена в информационно-технический справочник
# НДТ, что сопровождается специальными указаниями на особое мнение и допускается
# при соблюдении следующих условий:
#       а) в основе особого мнения лежат данные, которыми располагает ТРГ и
# федеральный орган исполнительной власти, ответственный за разработку
# информационно-технических справочников НДТ, на момент подготовки выводов
# относительно НДТ;
#       б) заинтересованными членами ТРГ представлены обоснованные доводы для
# включения технологии в перечень НДТ. Доводы являются обоснованными, если они
# подтверждаются техническими и экономическими данными, данными о воздействии на
# различные компоненты окружающей среды, соответствием рассматриваемой
# технологии понятию «наилучшая доступная технология» и критериям определения
# НДТ в соответствии с Федеральным законом от 10 января 2002 г. № 7-ФЗ «Об охране
# окружающей среды»
#
# Reference answer: Да, технология может быть определена в качестве НДТ даже если у членов ТРГ нет единогласного согласия. Сперва будет обсуждено компромиссное решение, а при возникновении серьезных разногласий будет проведена более глубокая комлексная оценка технологии. Если особое мнение основано на достоверных данных и обоснованных доводах, технология может быть включена в справочник НДТ с указанием особого мнения.
#
# RAW answer: К сожалению, ответа на вопрос нет в упомянутых источниках.
#
# RAW judgment: {'comment': 'The model answer inappropriately refuses to provide an answer, despite the reference clearly containing the necessary information to answer the question. The reference explicitly states that a technology can be defined as НДТ even without unanimous agreement among ТРГ members, provided certain conditions are met.', 'score': 2, 'is_correct': 0, 'is_inappropriate_refusal': 1}
#
# BASELINE answer: Да, технология нефтедобычи может быть признана наилучшей доступной технологией (НДТ) даже если среди членов ТРГ нет единогласного согласия, если все члены ТРГ имеют обоснованные доводы для включения технологии в перечень НДТ и представили эти доводы в форме специальных указаний на особое мнение и соблюдают критерии определения НДТ в соответствии с Федеральным законом от 10 января 2002 года № 7 ФЗ «Об охране окружающей среды».
#
# BASELINE judgment: {'comment': "The model answer is mostly correct but contains a minor inaccuracy. It states that 'если все члены ТРГ имеют обоснованные доводы для включения технологии в перечень НДТ,' which is not entirely accurate. The reference answer mentions that the technology can be included even if there is no unanimous agreement, provided that the special opinion is based on reliable data and justified arguments. The model answer does not fully capture the nuance of the reference answer regarding the possibility of inclusion without unanimous agreement.", 'score': 4, 'is_correct': 1, 'is_inappropriate_refusal': 0}
#
# -----------------------------------------------------------------
#
# -----------------------------------------------------------------
#
# Question: Что называют горизонтальной скважиной?
#
# Relevant context: Горизонтальной скважиной (или горизонтальным стволом скважины) называют
# скважину, у которой угол отклонения ствола от вертикали составляет 80 – 90°. Но здесь
# есть один нюанс. Так как «в природе нет прямых линий» и продуктивные
# нефтенасыщенные пласты залегают в недрах земли, как правило, с некоторым
# наклоном, а часто с довольно крутым наклоном, то на практике получается, что нет
# никакого смысла бурить горизонтальную скважину под углом, приблизительно равным
# 90°. Логичнее пробурить ствол скважины вдоль пласта по наиболее оптимальной
# траектории. Поэтому в более широком смысле под горизонтальной скважиной
# понимают скважину, имеющую протяженную фильтровую зону – ствол, пробуренный
# преимущественно вдоль напластования целевого пласта в определенном
# азимутальном направлении.
#
# Reference answer: Горизонтальной скважиной называют скважину, у которой угол отклонения ствола от вертикали составляет 80–90°. В более широком смысле под горизонтальной скважиной понимают скважину, имеющую протяженную фильтровую зону – ствол, пробуренный преимущественно вдоль напластования целевого пласта в определенном азимутальном направлении.
#
# RAW answer: Горизонтальная скважина - это скважина, у которой угол отклонения ствола от вертикали составляет 80-90°.
#
# RAW judgment: {'comment': 'The model answer correctly identifies the angle deviation of a horizontal well but omits the broader definition provided in the reference answer, which includes the concept of a well drilled predominantly along the target formation. This omission makes the answer incomplete.', 'score': 3, 'is_correct': 0, 'is_inappropriate_refusal': 0}
#
# BASELINE answer: Горизонтальная скважина - это скважина, у которой угол отклонения ствола от вертикали составляет 80-90°, а иногда даже больше 90°. Горизонтальная скважина является скважиной, которая имеет протяженную фильтровую зону и ствол, пробуренный преимущественно вдоль пласта целевого пласта в определенном азимутальном направлении.
#
# BASELINE judgment: {'comment': "The model answer correctly defines a horizontal well as having an angle of deviation from the vertical of 80-90° and mentions the extended filter zone drilled along the target formation. However, it incorrectly states 'sometimes even more than 90°', which is not supported by the context or reference. This inaccuracy affects the factual correctness of the answer.", 'score': 3, 'is_correct': 0, 'is_inappropriate_refusal': 0}
#
# -----------------------------------------------------------------
#
# -----------------------------------------------------------------
#
# Question: Што такоэ гаризантальная скважена?
#
# Relevant context: Горизонтальной скважиной (или горизонтальным стволом скважины) называют
# скважину, у которой угол отклонения ствола от вертикали составляет 80 – 90°. Но здесь
# есть один нюанс. Так как «в природе нет прямых линий» и продуктивные
# нефтенасыщенные пласты залегают в недрах земли, как правило, с некоторым
# наклоном, а часто с довольно крутым наклоном, то на практике получается, что нет
# никакого смысла бурить горизонтальную скважину под углом, приблизительно равным
# 90°. Логичнее пробурить ствол скважины вдоль пласта по наиболее оптимальной
# траектории. Поэтому в более широком смысле под горизонтальной скважиной
# понимают скважину, имеющую протяженную фильтровую зону – ствол, пробуренный
# преимущественно вдоль напластования целевого пласта в определенном
# азимутальном направлении.
#
# Reference answer: Горизонтальной скважиной называют скважину, у которой угол отклонения ствола от вертикали составляет 80–90°. В более широком смысле под горизонтальной скважиной понимают скважину, имеющую протяженную фильтровую зону – ствол, пробуренный преимущественно вдоль напластования целевого пласта в определенном азимутальном направлении.
#
# RAW answer: Горизонтальная скважина (или горизонтальный ствол скважины) - это тип скважины, где угол отклонения ствола от вертикали составляет 80-90°. Однако, поскольку в природе нет прямых линий и продуктивные нефтенасыщенные пласты залегают в недрах земли с некоторым наклоном, иногда горизонтальные скважины могут быть слишком наклонены для эффективной добычи нефти. Поэтому обычно пробуриваются стволы скважин вдоль пласта по наиболее оптимальной траектории, что делает горизонтальную скважину менее подходящим термином.
#
# RAW judgment: {'comment': "The model answer correctly identifies the angle deviation of a horizontal well (80-90°) but incorrectly suggests that horizontal wells are less suitable due to natural inclinations of oil-bearing layers. This contradicts the reference, which emphasizes that horizontal wells are drilled along the optimal trajectory of the target layer, making them highly suitable. The model's conclusion about the term being less suitable is misleading and not supported by the context.", 'score': 2, 'is_correct': 0, 'is_inappropriate_refusal': 0}
#
# BASELINE answer: Горизонтальная скважина - это скважина, у которой угол отклонения ствола от вертикали составляет 80-90 градусов. Горизонтальные скважины обычно используются для пробуривания скважин вдоль пласта целевого пласта, чтобы получить наибольшее количество продукта. Горизонтальные скважины также могут быть использованы для получения информации о геологии скважины, таких как глубина, длина и другие характеристики.
#
# BASELINE judgment: {'comment': 'The model answer correctly defines a horizontal well as having an angle deviation of 80-90 degrees from the vertical and mentions its use along the target formation. However, it introduces additional information about obtaining geological information, which is not mentioned in the reference answer and is not directly relevant to the definition of a horizontal well. This addition slightly detracts from the focus and accuracy of the answer.', 'score': 4, 'is_correct': 1, 'is_inappropriate_refusal': 0}
#
# -----------------------------------------------------------------
#
# -----------------------------------------------------------------
#
# Question: Привет! Мне нужна помощь, очень срочно! Дело в том, что я готовлюсь к экзамену, и у меня тут путаница с определениями. Можешь объяснить, что такое горизонтальная скважина? А то в учебнике всё как-то сложно написано, я запутался.
#
# Relevant context: Горизонтальной скважиной (или горизонтальным стволом скважины) называют
# скважину, у которой угол отклонения ствола от вертикали составляет 80 – 90°. Но здесь
# есть один нюанс. Так как «в природе нет прямых линий» и продуктивные
# нефтенасыщенные пласты залегают в недрах земли, как правило, с некоторым
# наклоном, а часто с довольно крутым наклоном, то на практике получается, что нет
# никакого смысла бурить горизонтальную скважину под углом, приблизительно равным
# 90°. Логичнее пробурить ствол скважины вдоль пласта по наиболее оптимальной
# траектории. Поэтому в более широком смысле под горизонтальной скважиной
# понимают скважину, имеющую протяженную фильтровую зону – ствол, пробуренный
# преимущественно вдоль напластования целевого пласта в определенном
# азимутальном направлении.
#
# Reference answer: Горизонтальной скважиной называют скважину, у которой угол отклонения ствола от вертикали составляет 80–90°. В более широком смысле под горизонтальной скважиной понимают скважину, имеющую протяженную фильтровую зону – ствол, пробуренный преимущественно вдоль напластования целевого пласта в определенном азимутальном направлении.
#
# RAW answer: К сожалению, ответа на вопрос нет в упомянутых источниках.
#
# RAW judgment: {'comment': 'The model answer is an inappropriate refusal since the relevant context clearly contains the information needed to answer the question. The reference answer provides a clear and accurate definition of a horizontal well, which the model failed to deliver.', 'score': 2, 'is_correct': 0, 'is_inappropriate_refusal': 1}
#
# BASELINE answer: Горизонтальная скважина - это скважина, у которой угол отклонения ствола от вертикали составляет 80-90°, но здесь есть один нюанс. Как правило, с некоторым наклоном, как правило, с довольно крутым наклоном, на практике получается, что нет никакого смысла бурить горизонтальную скважину под углом, приблизительно равным 90°. Логично пробурить ствол скважины вдоль пласта по наиболее оптимальной траектории.
#
# BASELINE judgment: {'comment': 'The model answer partially captures the definition of a horizontal well but misses the broader interpretation mentioned in the reference answer. It correctly states the angle deviation but fails to include the concept of the extended filter zone drilled along the target formation. Additionally, the phrasing is somewhat redundant and unclear.', 'score': 3, 'is_correct': 0, 'is_inappropriate_refusal': 0}
#
# -----------------------------------------------------------------
#
# -----------------------------------------------------------------
#
# Question: Какой тип скважины бурят так, чтобы её ствол проходил преимущественно вдоль залегающего под землёй продуктивного слоя?
#
# Relevant context: Горизонтальной скважиной (или горизонтальным стволом скважины) называют
# скважину, у которой угол отклонения ствола от вертикали составляет 80 – 90°. Но здесь
# есть один нюанс. Так как «в природе нет прямых линий» и продуктивные
# нефтенасыщенные пласты залегают в недрах земли, как правило, с некоторым
# наклоном, а часто с довольно крутым наклоном, то на практике получается, что нет
# никакого смысла бурить горизонтальную скважину под углом, приблизительно равным
# 90°. Логичнее пробурить ствол скважины вдоль пласта по наиболее оптимальной
# траектории. Поэтому в более широком смысле под горизонтальной скважиной
# понимают скважину, имеющую протяженную фильтровую зону – ствол, пробуренный
# преимущественно вдоль напластования целевого пласта в определенном
# азимутальном направлении.
#
# Reference answer: Горизонтальной скважиной называют скважину, у которой угол отклонения ствола от вертикали составляет 80–90°. В более широком смысле под горизонтальной скважиной понимают скважину, имеющую протяженную фильтровую зону – ствол, пробуренный преимущественно вдоль напластования целевого пласта в определенном азимутальном направлении.
#
# RAW answer: Тип скважины, которая бурят таким образом, чтобы её ствол проходил преимущественно вдоль залегающего под землёй продуктивного слоя, называется горизонтальной скважиной.
#
# RAW judgment: {'comment': 'The model answer correctly identifies the type of well as a horizontal well, which aligns with the reference answer. However, it lacks the detailed explanation provided in the reference about the angle deviation and the extended filter zone. Despite this, the core meaning is preserved, making it factually correct.', 'score': 4, 'is_correct': 1, 'is_inappropriate_refusal': 0}
#
# BASELINE answer: Тип скважины, которая используется для пробуривания скважины, которая проходит преимущественно вдоль залегающего под землей продуктивного слоя, может быть любой из трех типов: скважина с перфорированным забоем, скважина с забойным хвостовиком и скважина с забойным фильтром.
#
# BASELINE judgment: {'comment': 'The model answer is incorrect as it mentions three types of wells that are not relevant to the question about horizontal wells. The reference answer clearly defines a horizontal well as one drilled along the productive layer, which is the correct response. The model answer does not address the question accurately and introduces irrelevant information.', 'score': 1, 'is_correct': 0, 'is_inappropriate_refusal': 0}
#
# -----------------------------------------------------------------
#
# -----------------------------------------------------------------
#
# Question: Горизонтальная скважина — это такая скважина, которая всегда пробурена под углом ровно 90° к вертикали, верно?
#
# Relevant context: Горизонтальной скважиной (или горизонтальным стволом скважины) называют
# скважину, у которой угол отклонения ствола от вертикали составляет 80 – 90°. Но здесь
# есть один нюанс. Так как «в природе нет прямых линий» и продуктивные
# нефтенасыщенные пласты залегают в недрах земли, как правило, с некоторым
# наклоном, а часто с довольно крутым наклоном, то на практике получается, что нет
# никакого смысла бурить горизонтальную скважину под углом, приблизительно равным
# 90°. Логичнее пробурить ствол скважины вдоль пласта по наиболее оптимальной
# траектории. Поэтому в более широком смысле под горизонтальной скважиной
# понимают скважину, имеющую протяженную фильтровую зону – ствол, пробуренный
# преимущественно вдоль напластования целевого пласта в определенном
# азимутальном направлении.
#
# Reference answer: Нет, это не совсем так. Хотя горизонтальной скважиной называют скважину, у которой угол отклонения ствола от вертикали составляет 80–90°, на практике бурение под углом ровно 90° не имеет смысла. Более логично пробурить ствол вдоль пласта по оптимальной траектории. В более широком смысле горизонтальная скважина – это скважина, имеющая протяжённую фильтровую зону и пробуренная вдоль напластования целевого пласта в определённом азимутальном направлении.
#
# RAW answer: Нет, горизонтальная скважина — это скважина, где угол отклонения ствола от вертикали составляет 80-90°. Однако, как указано в контексте, на практике горизонтальная скважина обычно пробуряется вдоль пласта по оптимальной траектории, чтобы минимизировать влияние наклона пласта.
#
# RAW judgment: {'comment': 'The model answer is factually correct and aligns with the reference answer. It correctly states that a horizontal well has an angle deviation of 80-90° from the vertical and emphasizes the practical approach of drilling along the optimal trajectory of the formation. The core meaning is preserved, and there are no inaccuracies.', 'score': 5, 'is_correct': 1, 'is_inappropriate_refusal': 0}
#
# BASELINE answer: Нет, горизонтальная скважина - это не такая скважина, которая всегда пробурена под углом ровно 90° к вертикали. Горизонтальная скважина - это скважина, у которой угол отклонения ствола от вертикали составляет 80-90°. Однако, поскольку в природе нет прямых линий и продуктивные нефтенасыщенные пласты залегают в недрах земли, как правило, с некоторым наклоном, а часто с довольно крутым наклоном, на практике получается, что нет никакого смысла бурить горизонтальную скважину под углом, приблизительно равным 90°.
#
# BASELINE judgment: {'comment': 'The model answer correctly states that a horizontal well is not always drilled at exactly 90° to the vertical and explains the practical reasons for this, aligning with the reference answer. However, it misses the broader definition of a horizontal well as having a long filter zone drilled along the target formation, which is a key part of the reference answer. Despite this omission, the core information is accurate and relevant.', 'score': 4, 'is_correct': 1, 'is_inappropriate_refusal': 0}
#
# -----------------------------------------------------------------
#
# -----------------------------------------------------------------
#
# Question: Какие основные способы утилизации нефтяного газа получили наибольшее распространение в мировой практике?
#
# Relevant context: Сжигание ПНГ на факелах является источником больших выбросов в
#  атмосферу. Для снижения этого вида воздействия на предприятиях используются
#  установки подготовки ПНГ для его дальнейшего рационального использования, тем
#  самым уменьшается загрязнение воздуха.
#        К настоящему времени в мировой практике наибольшее распространение
# ...
#
#
# RAW answer: В мировой практике наибольшее распространение получили следующие способы утилизации нефтяного газа:
#
# 1. **Утилизация на месте добычи без переработки**: закачка в пласт с целью поддержания пластового давления, водогазовое воздействие, закачка в подземные хранилища газа для извлечения в будущем. Эти технологии сравнительно просты и практически не зависят от состава газа, но они достаточно энергоемки, и их применение ограничено геологическими особенностями залежей.
#
# 2. **Транспортировка газа или газожидкостной смеси мультифазным транспортом к месту переработки (на ГПЗ)**. Качество предварительной подготовки газа зависит от технических условий эксплуатации трубопровода.
#
# 3. **Закачка в газотранспортную сеть (ГТС)**. Требуется подготовка до требований нормативов.
#
# RAW judgment: {'comment': 'The model answer is mostly correct but incomplete. It misses the fourth method of utilization mentioned in the reference answer, which is the use of oil gas as fuel gas (Gas to Power-GTP) on gas piston and gas turbine power plants. This omission affects the completeness of the answer.', 'score': 4, 'is_correct': 1, 'is_inappropriate_refusal': 0}
#
# BASELINE answer: Основные способы утилизации нефтяного газа в мировой практике включают закачку в пласт с целью поддержания пластового давления, водогазовое воздействие, закачку в подземные хранилища газа для извлечения в будущем, транспортировку газа или газожидкостной смеси мультифазным транспортом к месту переработки, закачку в газотранспортную сеть (ГТС), использование в качестве топливного газа (Gas to Power GTP) на газо--поршневых (ГПЭС) и газотурбинных (ГТЭС) электростанциях для приводов компрессорного оборудования, синтез моторных топлив либо других продуктов (например, метанола) на месте, переработка мини ГПЗ на месторождении, сжижение нефтяного газа, транспортировка в виде газовых гидратов и другие методы утилизации, не получившие пока значительного распространения.
#
# BASELINE judgment: {'comment': 'The model answer is factually correct and comprehensive, covering all the methods mentioned in the reference answer and even extending to additional methods not widely used. However, it includes extra details which, while accurate, are not strictly necessary for answering the question. This makes the answer slightly redundant but does not detract from its correctness.', 'score': 5, 'is_correct': 1, 'is_inappropriate_refusal': 0}
#
# -----------------------------------------------------------------
#
# -----------------------------------------------------------------
#
# Question: Привет! Я тут делаю доклад по экологии, и мне срочно надо разобраться с утилизацией нефтяного газа. Как его вообще утилизируют, какие есть методы? Потому что я слышал, что его вроде просто сжигают, но, возможно, есть какие-то продвинутые технологии. Если можешь, расскажи подробно, буду благодарен!
#
# Relevant context: Сжигание ПНГ на факелах является источником больших выбросов в
#  атмосферу. Для снижения этого вида воздействия на предприятиях используются
#  установки подготовки ПНГ для его дальнейшего рационального использования, тем
#  самым уменьшается загрязнение воздуха.
#        К настоящему времени в мировой практике наибольшее распространение
#  получили следующие способы утилизации нефтяного газа:
#        1. Утилизация на месте добычи без переработки: закачка в пласт с целью
#  поддержания пластового давления; водогазовое воздействие; закачка в подземные
#  хранилища газа для извлечения в будущем. Технологии сравнительно просты и
#  практически не зависят от состава газа, однако они достаточно энергоемки, и их
#  применение ограничено геологическими особенностями залежей.
#        2. Транспортировка газа или газожидкостной смеси мультифазным транспортом
#  к месту переработки (на ГПЗ). Качество предварительной подготовки газа зависит от
#  технических условий эксплуатации трубопровода.
#        3. Закачка в газотранспортную сеть (ГТС). Требуется подготовка до требований
#  нормативов.
#        4. Использование в качестве топливного газа (Gas to Power-GTP) на газо-
#  поршневых (ГПЭС) и газотурбинных (ГТЭС) электростанциях для приводов
#  компрессорного оборудования. В зависимости от конкретной ситуации возможна
#  выработка электроэнергии как для собственных нужд, так и для энергообеспечения
#  других промышленных и гражданских объектов, а также поставки в электросети
#  (рисунок 3.3). Помимо перечисленных, разработан ряд других методов утилизации, не
#  получивших пока значительного распространения: синтез моторных топлив либо
#  других продуктов (например, метанола) на месте (Gas to Liquid – GTL); переработка
#  мини-ГПЗ на месторождении; сжижение нефтяного газа; транспортировка в виде
#  газовых гидратов и др.
#
# Reference answer: 1) Утилизация на месте добычи без переработки (закачка в пласт, водогазовое воздействие, закачка в подземные хранилища). 2) Транспортировка газа или газожидкостной смеси мультифазным транспортом к месту переработки (на ГПЗ). 3) Закачка в газотранспортную сеть (ГТС). 4) Использование в качестве топливного газа (Gas to Power-GTP) на газопоршневых (ГПЭС) и газотурбинных (ГТЭС) электростанциях.
#
# RAW answer: К сожалению, ответа на вопрос нет в упомянутых источниках.
#
# RAW judgment: {'comment': 'The model answer inappropriately refuses to provide an answer, despite the relevant context containing a full and detailed response to the question. This is an inappropriate refusal as the information is clearly available in the context.', 'score': 2, 'is_correct': 0, 'is_inappropriate_refusal': 1}
#
# BASELINE answer: Утилизация нефтяного газа может быть выполнена несколькими способами, включая закачку в пласт с целью поддержания пластового давления, водогазовое воздействие, закачку в подземные хранилища газа для извлечения в будущем, транспортировку газа или газожидкостной смеси мультифазным транспортом к месту переработки, а также закачку в газотранспортную сеть (ГТС). Кроме того, существует несколько методов подготовки ПНГ, таких как низкотемпературная сепарация, адсорбционная осушка, гликолевая осушка и сорбционные методы.
#
# BASELINE judgment: {'comment': 'The model answer is mostly correct but includes additional information about methods of preparing associated petroleum gas (APG) that was not requested in the question. The core methods of gas utilization mentioned align with the reference answer, but the inclusion of unrelated preparation methods detracts from the focus on utilization. This makes the answer partially correct but somewhat redundant.', 'score': 3, 'is_correct': 1, 'is_inappropriate_refusal': 0}
#
# -----------------------------------------------------------------
#
# -----------------------------------------------------------------
#
# Question: Какие существуют основные методы переработки сопутствующего газа с минимальными выбросами в атмосферу, применяемые в промышленности?
#
# Relevant context: Сжигание ПНГ на факелах является источником больших выбросов в
#  атмосферу. Для снижения этого вида воздействия на предприятиях используются
#  установки подготовки ПНГ для его дальнейшего рационального использования, тем
#  самым уменьшается загрязнение воздуха.
#        К настоящему времени в мировой практике наибольшее распространение
#  получили следующие способы утилизации нефтяного газа:
#        1. Утилизация на месте добычи без переработки: закачка в пласт с целью
#  поддержания пластового давления; водогазовое воздействие; закачка в подземные
#  хранилища газа для извлечения в будущем. Технологии сравнительно просты и
#  практически не зависят от состава газа, однако они достаточно энергоемки, и их
#  применение ограничено геологическими особенностями залежей.
#        2. Транспортировка газа или газожидкостной смеси мультифазным транспортом
#  к месту переработки (на ГПЗ). Качество предварительной подготовки газа зависит от
#  технических условий эксплуатации трубопровода.
#        3. Закачка в газотранспортную сеть (ГТС). Требуется подготовка до требований
#  нормативов.
#        4. Использование в качестве топливного газа (Gas to Power-GTP) на газо-
#  поршневых (ГПЭС) и газотурбинных (ГТЭС) электростанциях для приводов
#  компрессорного оборудования. В зависимости от конкретной ситуации возможна
#  выработка электроэнергии как для собственных нужд, так и для энергообеспечения
#  других промышленных и гражданских объектов, а также поставки в электросети
#  (рисунок 3.3). Помимо перечисленных, разработан ряд других методов утилизации, не
#  получивших пока значительного распространения: синтез моторных топлив либо
#  других продуктов (например, метанола) на месте (Gas to Liquid – GTL); переработка
#  мини-ГПЗ на месторождении; сжижение нефтяного газа; транспортировка в виде
#  газовых гидратов и др.
#
# Reference answer: 1) Утилизация на месте добычи без переработки (закачка в пласт, водогазовое воздействие, закачка в подземные хранилища). 2) Транспортировка газа или газожидкостной смеси мультифазным транспортом к месту переработки (на ГПЗ). 3) Закачка в газотранспортную сеть (ГТС). 4) Использование в качестве топливного газа (Gas to Power-GTP) на газопоршневых (ГПЭС) и газотурбинных (ГТЭС) электростанциях.
#
#
# RAW answer: Основные методы переработки сопутствующего газа с минимальными выбросами в атмосферу, применяемые в промышленности, включают:
#
# 1. **Низкотемпературная сепарация** - позволяет разделить газ на различные компоненты, минимизируя выбросы вредных веществ.
# 2. **Адсорбционная осушка** - эффективно удаляет влагу из газа, обеспечивая минимальные выбросы.
# 3. **Сорбционные методы** - обеспечивают удаление сероводорода и других вредных веществ.
# 4. **Гликолевая осушка** - используется для удаления воды, минимизируя выбросы.
# 5. **Методы низкотемпературной сепарации** и **адсорбционной осушки** - подходят для подготовки ПНГ для дальнейшего использования, минимизируя выбросы вредных веществ.
#
# Эти методы помогают сохранять экологическую чистоту, минимизируя выбросы вредных веществ в атмосферу, что важно для защиты окружающей среды.
#
# RAW judgment: {'comment': 'The model answer does not align with the reference answer or the provided context. It introduces methods like low-temperature separation, adsorption drying, sorption methods, and glycol dehydration, which are not mentioned in the context or reference answer. The reference answer focuses on methods like utilization at the extraction site, transportation to processing plants, injection into gas transmission networks, and use as fuel gas. The model answer is factually incorrect and irrelevant to the question.', 'score': 1, 'is_correct': 0, 'is_inappropriate_refusal': 0}
#
# BASELINE answer: Основные методы переработки сопутствующего газа с минимальными выбросами в атмосферу включают в себя сепарационные методы, такие как сепарация, газодинамические методы, такие как газодинамические методы, сорбционные методы, такие как сорбционные методы, и гликолевая осушка. Эти методы имеют различные преимущества и ограничения, и каждая может быть использована в различных условиях.
#
# BASELINE judgment: {'comment': 'The model answer does not align with the reference answer or the relevant context provided. It mentions methods like сепарация, газодинамические методы, сорбционные методы, and гликолевая осушка, which are not discussed in the context or the reference answer. The reference answer focuses on methods like утилизация на месте добычи, транспортировка газа, закачка в газотранспортную сеть, and использование в качестве топливного газа. Therefore, the model answer is factually incorrect and irrelevant to the question.', 'score': 1, 'is_correct': 0, 'is_inappropriate_refusal': 0}
#
# -----------------------------------------------------------------
#
# -----------------------------------------------------------------
#
# Question: Правда ли, что нефтяной газ невозможно утилизировать, и его единственным методом утилизации является сжигание на факелах?
#
# Relevant context: Сжигание ПНГ на факелах является источником больших выбросов в
#  атмосферу. Для снижения этого вида воздействия на предприятиях используются
#  установки подготовки ПНГ для его дальнейшего рационального использования, тем
#  самым уменьшается загрязнение воздуха.
#        К настоящему времени в мировой практике наибольшее распространение
#  получили следующие способы утилизации нефтяного газа:
#        1. Утилизация на месте добычи без переработки: закачка в пласт с целью
#  поддержания пластового давления; водогазовое воздействие; закачка в подземные
#  хранилища газа для извлечения в будущем. Технологии сравнительно просты и
#  практически не зависят от состава газа, однако они достаточно энергоемки, и их
#  применение ограничено геологическими особенностями залежей.
#        2. Транспортировка газа или газожидкостной смеси мультифазным транспортом
#  к месту переработки (на ГПЗ). Качество предварительной подготовки газа зависит от
#  технических условий эксплуатации трубопровода.
#        3. Закачка в газотранспортную сеть (ГТС). Требуется подготовка до требований
#  нормативов.
#        4. Использование в качестве топливного газа (Gas to Power-GTP) на газо-
#  поршневых (ГПЭС) и газотурбинных (ГТЭС) электростанциях для приводов
#  компрессорного оборудования. В зависимости от конкретной ситуации возможна
#  выработка электроэнергии как для собственных нужд, так и для энергообеспечения
#  других промышленных и гражданских объектов, а также поставки в электросети
#  (рисунок 3.3). Помимо перечисленных, разработан ряд других методов утилизации, не
#  получивших пока значительного распространения: синтез моторных топлив либо
#  других продуктов (например, метанола) на месте (Gas to Liquid – GTL); переработка
#  мини-ГПЗ на месторождении; сжижение нефтяного газа; транспортировка в виде
#  газовых гидратов и др.
#
# Reference answer: Это неверно. Хотя сжигание ПНГ на факелах действительно приводит к большим выбросам в атмосферу, существуют различные методы его утилизации. Основные из них включают: 1) Утилизацию на месте добычи без переработки (закачка в пласт, водогазовое воздействие, закачка в подземные хранилища). 2) Транспортировку газа или газожидкостной смеси мультифазным транспортом к месту переработки (на ГПЗ). 3) Закачку в газотранспортную сеть (ГТС). 4) Использование в качестве топливного газа (Gas to Power-GTP) на газопоршневых (ГПЭС) и газотурбинных (ГТЭС) электростанциях.
#
# RAW answer: Нет, это не правда. Нефтяной газ можно утилизировать несколькими способами, включая закачку в пласт, водогазовое воздействие, закачку в подземные хранилища для извлечения в будущем, транспортировку газа или газожидкостной смеси мультифазным транспортом к месту переработки, а также через газотранспортную сеть.
#
# RAW judgment: {'comment': 'The model answer is factually correct and covers the main methods of utilizing petroleum gas as mentioned in the reference answer. However, it omits some details like the use of gas as fuel in power plants (Gas to Power-GTP), which is present in the reference. Despite this minor omission, the core information is accurate and complete enough to convey the same meaning as the reference.', 'score': 4, 'is_correct': 1, 'is_inappropriate_refusal': 0}
#
# BASELINE answer: Да, правда, что нефтяной газ нельзя утилизировать, и его единственным методом утилизации является сжигание на факелах.
#
# BASELINE judgment: {'comment': 'The model answer is factually incorrect and directly contradicts the reference answer and the provided context. It falsely claims that the only method of disposal for oil gas is burning in flares, while the context and reference clearly outline multiple methods of utilization. This answer fails to convey any correct information on the topic.', 'score': 1, 'is_correct': 0, 'is_inappropriate_refusal': 0}
#
# -----------------------------------------------------------------
#
#
#
#
#
# RAW avg score: 3.0
# BASELINE avg score: 2.9

# %%
with open("scored_simple/qwen-1.5b-baseline.json", "r") as baseline:
    baseline = json.load(baseline)

    avg_baseline = 0

    for i, item in enumerate(baseline):
        # print("-----------------------------------------------------------------\n")
        # print(f"Question: {raw[i]['table_data']['Вопрос']}\n")
        # print(f"Relevant context: {raw[i]['table_data']['Отрывок из документа']}\n")
        # print(f"Reference answer: {raw[i]['table_data']['Ответ']}\n")
        # print(f"RAW answer: {raw[i]['model_answer']}\n")
        # print(f"RAW judgment: {raw[i]['judgment']}\n")
        # print(f"BASELINE answer: {baseline[i]['model_answer']}\n")
        # print(f"BASELINE judgment: {baseline[i]['judgment']}\n")
        # print("-----------------------------------------------------------------\n")

        avg_baseline += item["judgment"]["score"]

    print("\n\n\n")
    print(f"BASELINE avg score: {avg_baseline / len(baseline)}")
# Out:
# BASELINE avg score: 2.8175074183976263

# %%
with open("scored_simple/qwen-1.5b-raw.json", "r") as baseline:
    baseline = json.load(baseline)

    avg_baseline = 0

    for i, item in enumerate(baseline):
        # print("-----------------------------------------------------------------\n")
        # print(f"Question: {raw[i]['table_data']['Вопрос']}\n")
        # print(f"Relevant context: {raw[i]['table_data']['Отрывок из документа']}\n")
        # print(f"Reference answer: {raw[i]['table_data']['Ответ']}\n")
        # print(f"RAW answer: {raw[i]['model_answer']}\n")
        # print(f"RAW judgment: {raw[i]['judgment']}\n")
        # print(f"BASELINE answer: {baseline[i]['model_answer']}\n")
        # print(f"BASELINE judgment: {baseline[i]['judgment']}\n")
        # print("-----------------------------------------------------------------\n")

        avg_baseline += item["judgment"]["score"]

    print("\n\n\n")
    print(f"BASELINE avg score: {avg_baseline / len(baseline)}")
# Out:
# BASELINE avg score: 2.986646884272997

# %%
with open("scored_sbs/qwen-3b-raw-vs-qwen-3b-raft.json", "r") as f:
    data = json.load(f)

    even = 0
    raw = 0
    baseline = 0


    for i, item in enumerate(data):
        # print("-----------------------------------------------------------------\n")
        # print(f"Question: {raw[i]['table_data']['Вопрос']}\n")
        # print(f"Relevant context: {raw[i]['table_data']['Отрывок из документа']}\n")
        # print(f"Reference answer: {raw[i]['table_data']['Ответ']}\n")
        # print(f"RAW answer: {raw[i]['model_answer']}\n")
        # print(f"RAW judgment: {raw[i]['judgment']}\n")
        # print(f"BASELINE answer: {baseline[i]['model_answer']}\n")
        # print(f"BASELINE judgment: {baseline[i]['judgment']}\n")
        # print("-----------------------------------------------------------------\n")

        try:
            winner = item["judgment"]["winner"]
        except:
            winner = 2
        if winner == 0:
            even+=1
        elif winner == 1:
            raw+=1
        else:
            baseline+=1

    print("\n\n\n")
    print(f"even: {even / len(data)}")
    print(f"raw: {raw / len(data)}")
    print(f"baseline: {baseline / len(data)}")
# Out:
# even: 0.032640949554896145
# raw: 0.5504451038575667
# baseline: 0.4169139465875371
