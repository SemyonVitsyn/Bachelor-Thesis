# %%
import os
import re
import torch
from multiprocessing import Pool
from docling.document_converter import DocumentConverter

os.environ["OMP_NUM_THREADS"] = "12"

def decode_unicode_sequences(text):
    return re.sub(r"/uni([0-9a-fA-F]{4})", lambda m: chr(int(m.group(1), 16)), text)

def process_file(args):
    pdf_path, md_root, pdf_root = args
    try:
        converter = DocumentConverter()
        relative_path = os.path.relpath(pdf_path, pdf_root)
        md_path = os.path.join(md_root, os.path.splitext(relative_path)[0] + ".md")
        
        result = converter.convert(pdf_path)
        markdown_text = result.document.export_to_markdown()
        markdown_text = decode_unicode_sequences(markdown_text)

        os.makedirs(os.path.dirname(md_path), exist_ok=True)
        with open(md_path, "w", encoding="utf-8") as f:
            f.write(markdown_text)

        print(f"✅ Файл {pdf_path} сохранен в {md_path}")
        torch.cuda.empty_cache()
        return True
    except Exception as e:
        print(f"❌ Ошибка при обработке {pdf_path}: {e}")
        return False

def convert_all_pdfs(pdf_root="../pdf", md_root="../md_benchmark", workers=4):
    tasks = []
    for root, _, files in os.walk(pdf_root):
        for file in files:
            if file.lower().endswith(".pdf"):
                pdf_path = os.path.join(root, file)
                tasks.append((pdf_path, md_root, pdf_root))

    # Запускаем пул процессов
    with Pool(processes=workers) as pool:
        results = pool.map(process_file, tasks)
    
    print(f"Обработано {sum(results)} файлов из {len(tasks)}")

convert_all_pdfs(workers=3)
# Out:
# 2025-05-10 16:47:58.113958: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746884878.136140   25893 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746884878.143075   25893 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1746884878.161233   25893 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746884878.161250   25893 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746884878.161252   25893 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746884878.161255   25893 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-10 16:47:58.167288: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ✅ Файл ../pdf/benchmark/ai_industry_reports/investments3.pdf сохранен в ../md_benchmark/benchmark/ai_industry_reports/investments3.md
# ✅ Файл ../pdf/benchmark/oil/Нефтяная_и_газовая_промышленность.pdf сохранен в ../md_benchmark/benchmark/oil/Нефтяная_и_газовая_промышленность.md
# ✅ Файл ../pdf/benchmark/ai_industry_reports/strategy3.pdf сохранен в ../md_benchmark/benchmark/ai_industry_reports/strategy3.md
# ✅ Файл ../pdf/benchmark/ai_industry_reports/report3.pdf сохранен в ../md_benchmark/benchmark/ai_industry_reports/report3.md
# ✅ Файл ../pdf/benchmark/ai_industry_reports/trends3.pdf сохранен в ../md_benchmark/benchmark/ai_industry_reports/trends3.md
# ✅ Файл ../pdf/benchmark/linux/linux.pdf сохранен в ../md_benchmark/benchmark/linux/linux.md
# ✅ Файл ../pdf/benchmark/ai_industry_reports/index3.pdf сохранен в ../md_benchmark/benchmark/ai_industry_reports/index3.md
# ✅ Файл ../pdf/benchmark/oil/ИТС-28-2017_добыча_нефти.pdf сохранен в ../md_benchmark/benchmark/oil/ИТС-28-2017_добыча_нефти.md
# ✅ Файл ../pdf/benchmark/technical_instructions/1c.pdf сохранен в ../md_benchmark/benchmark/technical_instructions/1c.md
# ✅ Файл ../pdf/benchmark/oil/Проектная_документация_для_освоения_морских_месторождений.pdf сохранен в ../md_benchmark/benchmark/oil/Проектная_документация_для_освоения_морских_месторождений.md
# ✅ Файл ../pdf/benchmark/technical_instructions/mysql.pdf сохранен в ../md_benchmark/benchmark/technical_instructions/mysql.md
# ✅ Файл ../pdf/benchmark/analytical_reports/centralbank2.pdf сохранен в ../md_benchmark/benchmark/analytical_reports/centralbank2.md
# ✅ Файл ../pdf/benchmark/analytical_reports/macro2.pdf сохранен в ../md_benchmark/benchmark/analytical_reports/macro2.md
# ✅ Файл ../pdf/benchmark/analytical_reports/smartcities2.pdf сохранен в ../md_benchmark/benchmark/analytical_reports/smartcities2.md
# ✅ Файл ../pdf/benchmark/operating_instructions/refrigerator.pdf сохранен в ../md_benchmark/benchmark/operating_instructions/refrigerator.md
# ✅ Файл ../pdf/benchmark/analytical_reports/transport2.pdf сохранен в ../md_benchmark/benchmark/analytical_reports/transport2.md
# ✅ Файл ../pdf/benchmark/analytical_reports/commerce2.pdf сохранен в ../md_benchmark/benchmark/analytical_reports/commerce2.md
# ✅ Файл ../pdf/benchmark/operating_instructions/snowmobile.pdf сохранен в ../md_benchmark/benchmark/operating_instructions/snowmobile.md
# ✅ Файл ../pdf/benchmark/operating_instructions/snow_plow.pdf сохранен в ../md_benchmark/benchmark/operating_instructions/snow_plow.md
# ✅ Файл ../pdf/benchmark/operating_instructions/microwave.pdf сохранен в ../md_benchmark/benchmark/operating_instructions/microwave.md
# ✅ Файл ../pdf/benchmark/medicine/Современные_молекулярные_подходы_к_диагностике_и_лечению_низкодифференцированных_глиом.pdf сохранен в ../md_benchmark/benchmark/medicine/Современные_молекулярные_подходы_к_диагностике_и_лечению_низкодифференцированных_глиом.md
# ✅ Файл ../pdf/benchmark/medicine/Рекомендации_по_диагностике_и_лечению_тяжелой_черепно-мозговой_травмы_Часть_1_Организация_медицинской_помощи_и_диагностика.pdf сохранен в ../md_benchmark/benchmark/medicine/Рекомендации_по_диагностике_и_лечению_тяжелой_черепно-мозговой_травмы_Часть_1_Организация_медицинской_помощи_и_диагностика.md
# ✅ Файл ../pdf/benchmark/operating_instructions/android.pdf сохранен в ../md_benchmark/benchmark/operating_instructions/android.md
# ✅ Файл ../pdf/benchmark/medicine/Первичный_гипотиреоз_и_постменопауза_как_причины_отсроченной_диагностики_пангипопитуитаризма_у_пациентки_с_гормонально-неактивной.pdf сохранен в ../md_benchmark/benchmark/medicine/Первичный_гипотиреоз_и_постменопауза_как_причины_отсроченной_диагностики_пангипопитуитаризма_у_пациентки_с_гормонально-неактивной.md
# ✅ Файл ../pdf/benchmark/medicine/Дискордантные_показатели_инсулиноподобного_фактора_роста_1_(ИФР-1)_и_соматотропина_(СТГ)_в_диагностике_и_мониторинге_акромегалии.pdf сохранен в ../md_benchmark/benchmark/medicine/Дискордантные_показатели_инсулиноподобного_фактора_роста_1_(ИФР-1)_и_соматотропина_(СТГ)_в_диагностике_и_мониторинге_акромегалии.md
# ✅ Файл ../pdf/benchmark/medicine/Обзор_клинических_рекомендаций_по_гипопаратиреозу.pdf сохранен в ../md_benchmark/benchmark/medicine/Обзор_клинических_рекомендаций_по_гипопаратиреозу.md
# ✅ Файл ../pdf/benchmark/medicine/Современные_методы_диагностики_и_лечения_детей_с_врожденными_базальными_черепно-мозговыми_грыжами.pdf сохранен в ../md_benchmark/benchmark/medicine/Современные_методы_диагностики_и_лечения_детей_с_врожденными_базальными_черепно-мозговыми_грыжами.md
# ✅ Файл ../pdf/benchmark/medicine/Рекомендации_по_диагностике_и_лечению_тяжелой_черепно-мозговой_травмы_Часть_3_Хирургическое_лечение_(опции).pdf сохранен в ../md_benchmark/benchmark/medicine/Рекомендации_по_диагностике_и_лечению_тяжелой_черепно-мозговой_травмы_Часть_3_Хирургическое_лечение_(опции).md
# ✅ Файл ../pdf/benchmark/medicine/Акромегалия_при_дифференциальной_диагностике_тугоухости.pdf сохранен в ../md_benchmark/benchmark/medicine/Акромегалия_при_дифференциальной_диагностике_тугоухости.md
# ✅ Файл ../pdf/benchmark/medicine/Диабетическая_гастроэнтеропатия_современные_методы_диагностики_и_лечения.pdf сохранен в ../md_benchmark/benchmark/medicine/Диабетическая_гастроэнтеропатия_современные_методы_диагностики_и_лечения.md
# ✅ Файл ../pdf/benchmark/medicine/Применение_методов_машинного_обучения_в_дифференциальной_диагностике_АКТГ-зависимого_эндогенного_гиперкортицизма.pdf сохранен в ../md_benchmark/benchmark/medicine/Применение_методов_машинного_обучения_в_дифференциальной_диагностике_АКТГ-зависимого_эндогенного_гиперкортицизма.md
# ✅ Файл ../pdf/benchmark/medicine/Диагностика_психогенной_полидипсии_на_примере_клинического_случая.pdf сохранен в ../md_benchmark/benchmark/medicine/Диагностика_психогенной_полидипсии_на_примере_клинического_случая.md
# ✅ Файл ../pdf/benchmark/financial_reports/gazprom1.pdf сохранен в ../md_benchmark/benchmark/financial_reports/gazprom1.md
# ✅ Файл ../pdf/benchmark/metal/ИТС_11-2019_Производство_алюминия.pdf сохранен в ../md_benchmark/benchmark/metal/ИТС_11-2019_Производство_алюминия.md
# ✅ Файл ../pdf/benchmark/financial_reports/aeroflot1.pdf сохранен в ../md_benchmark/benchmark/financial_reports/aeroflot1.md
# ✅ Файл ../pdf/benchmark/financial_reports/megafon1.pdf сохранен в ../md_benchmark/benchmark/financial_reports/megafon1.md
# ✅ Файл ../pdf/test/microwave.pdf сохранен в ../md_benchmark/test/microwave.md
# ✅ Файл ../pdf/test/dicer1.pdf сохранен в ../md_benchmark/test/dicer1.md
# ✅ Файл ../pdf/benchmark/metal/ИТС_26-2017_Производство_чугуна_стали_и_ферросплавов.pdf сохранен в ../md_benchmark/benchmark/metal/ИТС_26-2017_Производство_чугуна_стали_и_ферросплавов.md
# Обработано 49 файлов из 49
